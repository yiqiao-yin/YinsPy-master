# %% [markdown]
# # YIN'S MONEY MANAGEMENT (YINSMM): Starter Code to Investigate Company Profile
#
# This notebook loads a script and runs through starting code to investigate company profile.

# %% [markdown]
# ### Load Script
#
# Let us start by loading the ".py" script from local environment. Notice that you should have "YinsMM.py" file stored in your local environment under a path you prefer.

# %%
# %run "../scripts/YinsMM.py"
# Out:
# -----------------------------------------------------
#
#         Yin's Money Managmeent Package
#         Copyright © YINS CAPITAL, 2009 – Present
#
# -----------------------------------------------------

# %% [markdown]
# ### Run Function
#
# Next, let us set up starting date and ending date for the data that you like and specify a stock ticker you want to look at.
#
# Note: one can specify "verbose=True" which will print out a brief summary:
# - stock price charts with adjusted closing price and moving averages
# - time-series plot of signals (positive means sell and negative means buy assuming using reversal strategy)
# - expected return
# - expected risk (measured by volatility)
# - tail of buy signal (developed by myself; and transformation of moving averages; for more, please go to my research site [here](https://yinscapital.com/research/) and click on "Buy Signal from Limit Theorem".)

# %%
start_date = '2010-01-01'
end_date   = '2020-01-18'
ticker = 'FB'
temp = YinsMM.YinsTimer(start_date, end_date, ticker, 
                        figsize=(8,4), LB=-0.1, UB=0.1, 
                        plotGraph=True, verbose=True)
# Out:
# ------------------------------------------------------------------------------
# MANUAL:
# Try run the following line by line in a Python Notebook.
#
#             # Load
#             %run "../scripts/YinsMM.py"
#
#             # Run
#             start_date = '2010-01-01'
#             end_date   = '2020-01-18'
#             ticker = 'FB'
#             temp = YinsMM.YinsTimer(start_date, end_date, ticker,
#                                     figsize=(15,6), LB=-0.01, UB=0.01,
#                                     plotGraph=True, verbose=True)
#
# Manual ends here.
# ------------------------------------------------------------------------------
# [*********************100%***********************]  1 of 1 completed
# ----------------------------------------------------------------------------------------------------
# Entered Stock has the following information:
# Ticker: FB
# Expted Return: 0.0012
# Expted Risk (Volatility): 0.0227
# Reward-Risk Ratio (Daily Data): 0.0514
# Tail of the 'Buy/Sell Signal' dataframe:
#               Signal
# Date
# 2020-01-13  0.122318
# 2020-01-14  0.104676
# 2020-01-15  0.112032
# 2020-01-16  0.111950
# 2020-01-17  0.110858
# Note: positive values indicate 'sell' and negative values indicate 'buy'.
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# Once the code finishes running, we can start to print the result by looking at basic statistics such as expected return and risk. This will be exactly the same numbers from printed results from above.

# %%
print(f'Ticker: {ticker}')
print(f"Expted Return: {round(temp['estimatedReturn'], 4)}")
print(f"Expted Risk (Volatility): {round(temp['estimatedRisk'], 4)}")
print(f"Reward-Risk Ratio (Daily Data): {round(temp['estimatedReturn'] / temp['estimatedRisk'], 4)}")
# Out:
# Ticker: FB
# Expted Return: 0.0012
# Expted Risk (Volatility): 0.0227
# Reward-Risk Ratio (Daily Data): 0.0514

# %% [markdown]
# ### Further Exploration of Company's Profile
#
# If one wants to explore more, one can access 'ALL_DATA' which is a big dictionary stored rest available data downloaded from "yfinance" library.

# %%
# Give it a name:
ALL_DATA = temp['ALL_DATA']

# %%
print(f"Business Summary: {ALL_DATA['get stock info']['longBusinessSummary']}")
# Out:
# Business Summary: Facebook, Inc. provides various products to connect and share through mobile devices, personal computers, and other surfaces worldwide. The company's products include Facebook that enables people to connect, share, discover, and communicate with each other on mobile devices and personal computers; Instagram, a community for sharing photos, videos, and messages; Messenger, a messaging application for people to connect with friends, family, groups, and businesses across platforms and devices; and WhatsApp, a messaging application for use by people and businesses to communicate in a private way. It also provides Oculus, a hardware, software, and developer ecosystem, which allows people to come together and connect with each other through its Oculus virtual reality products. As of December 31, 2018, it had approximately 1.52 billion daily active users. The company was founded in 2004 and is headquartered in Menlo Park, California.

# %%
ALL_DATA['show balance sheet'][0] # annual report
# Out:
#                              2018-12-31    2017-12-31    2016-12-31  \
# Accounts Payable           8.200000e+08  3.800000e+08  3.020000e+08
# Capital Surplus            4.290600e+10  4.058400e+10  3.822700e+10
# Cash                       1.001900e+10  8.079000e+09  8.903000e+09
# Common Stock               4.290600e+10           NaN           NaN
# Good Will                  1.830100e+10  1.822100e+10  1.812200e+10
# Intangible Assets          1.294000e+09  1.884000e+09  2.535000e+09
# Net Receivables            7.587000e+09  5.832000e+09  3.993000e+09
# Net Tangible Assets        6.453200e+10  5.424200e+10  3.853700e+10
# Other Assets               2.576000e+09  2.135000e+09  1.312000e+09
# Other Current Assets       1.000000e+07  1.800000e+07           NaN
# Other Current Liab         4.494000e+09  2.590000e+09  1.937000e+09
# Other Liab                 6.190000e+09  6.417000e+09  2.892000e+09
# Other Stockholder Equity  -7.600000e+08 -2.270000e+08 -7.030000e+08
# Property Plant Equipment   2.468300e+10  1.372100e+10  8.591000e+09
# Retained Earnings          4.198100e+10  3.399000e+10  2.167000e+10
# Short Term Investments     3.109500e+10  3.363200e+10  2.054600e+10
# Total Assets               9.733400e+10  8.452400e+10  6.496100e+10
# Total Current Assets       5.048000e+10  4.856300e+10  3.440100e+10
# Total Current Liabilities  7.017000e+09  3.760000e+09  2.875000e+09
# Total Liab                 1.320700e+10  1.017700e+10  5.767000e+09
# Total Stockholder Equity   8.412700e+10  7.434700e+10  5.919400e+10
# Treasury Stock            -7.600000e+08 -2.270000e+08 -7.030000e+08
#
#                              2015-12-31
# Accounts Payable           1.960000e+08
# Capital Surplus            3.488600e+10
# Cash                       4.907000e+09
# Common Stock                        NaN
# Good Will                  1.802600e+10
# Intangible Assets          3.246000e+09
# Net Receivables            2.559000e+09
# Net Tangible Assets        2.294600e+10
# Other Assets               7.960000e+08
# Other Current Assets                NaN
# Other Current Liab         1.048000e+09
# Other Liab                 3.157000e+09
# Other Stockholder Equity  -4.550000e+08
# Property Plant Equipment   5.687000e+09
# Retained Earnings          9.787000e+09
# Short Term Investments     1.352700e+10
# Total Assets               4.940700e+10
# Total Current Assets       2.165200e+10
# Total Current Liabilities  1.925000e+09
# Total Liab                 5.189000e+09
# Total Stockholder Equity   4.421800e+10
# Treasury Stock            -4.550000e+08

# %%
ALL_DATA['show balance sheet'][1] # quarterly report
# Out:
#                              2019-09-30    2019-06-30    2019-03-31  \
# Accounts Payable           8.600000e+08  6.550000e+08  6.040000e+08
# Capital Surplus            4.505900e+10  4.427700e+10  4.353300e+10
# Cash                       1.597900e+10  1.387700e+10  1.107600e+10
# Common Stock                        NaN           NaN  4.353300e+10
# Good Will                  1.833800e+10  1.833400e+10  1.833300e+10
# Intangible Assets          8.530000e+08  9.940000e+08  1.150000e+09
# Net Receivables            7.673000e+09  7.513000e+09  6.475000e+09
# Net Tangible Assets        7.480800e+10  6.943400e+10  6.703300e+10
# Other Assets               2.461000e+09  2.446000e+09  2.602000e+09
# Other Current Assets       7.000000e+06  9.000000e+06  1.000000e+07
# Other Current Liab         8.150000e+08  7.758000e+09  6.790000e+08
# Other Liab                 8.735000e+09  7.749000e+09  6.148000e+09
# Other Stockholder Equity  -8.490000e+08 -4.830000e+08 -7.810000e+08
# Property Plant Equipment   4.068700e+10  3.727100e+10  3.409200e+10
# Retained Earnings          4.978900e+10  4.496800e+10  4.376400e+10
# Short Term Investments     3.629000e+10  3.471900e+10  3.416700e+10
# Total Assets               1.244180e+11  1.170060e+11  1.094770e+11
# Total Current Assets       6.207900e+10  5.796100e+10  5.330000e+10
# Total Current Liabilities  1.332800e+10  1.297900e+10  9.908000e+09
# Total Liab                 3.041900e+10  2.824400e+10  2.296100e+10
# Total Stockholder Equity   9.399900e+10  8.876200e+10  8.651600e+10
# Treasury Stock            -8.490000e+08 -4.830000e+08 -7.810000e+08
#
#                              2018-12-31
# Accounts Payable           8.200000e+08
# Capital Surplus            4.290600e+10
# Cash                       1.001900e+10
# Common Stock               4.290600e+10
# Good Will                  1.830100e+10
# Intangible Assets          1.294000e+09
# Net Receivables            7.587000e+09
# Net Tangible Assets        6.453200e+10
# Other Assets               2.576000e+09
# Other Current Assets       1.000000e+07
# Other Current Liab         4.494000e+09
# Other Liab                 6.190000e+09
# Other Stockholder Equity  -7.600000e+08
# Property Plant Equipment   2.468300e+10
# Retained Earnings          4.198100e+10
# Short Term Investments     3.109500e+10
# Total Assets               9.733400e+10
# Total Current Assets       5.048000e+10
# Total Current Liabilities  7.017000e+09
# Total Liab                 1.320700e+10
# Total Stockholder Equity   8.412700e+10
# Treasury Stock            -7.600000e+08

# %% [markdown]
# The notebook ends here.
