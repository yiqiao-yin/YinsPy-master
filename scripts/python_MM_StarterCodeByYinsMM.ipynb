# %% [markdown]
# # YIN'S MONEY MANAGEMENT (YINSMM): Starter Code to Investigate Company Profile
#
# This notebook loads a script and runs through starting code to investigate company profile.

# %% [markdown]
# ### Load Script
#
# Let us start by loading the ".py" script from local environment. Notice that you should have "YinsMM.py" file stored in your local environment under a path you prefer.

# %%
# %run "../scripts/YinsMM.py"

# %% [markdown]
# ### Run Function
#
# Next, let us set up starting date and ending date for the data that you like and specify a stock ticker you want to look at.
#
# Note: one can specify "verbose=True" which will print out a brief summary:
# - expected return
# - expected risk (measured by volatility)
# - tail of buy signal (developed by myself; and transformation of moving averages; for more, please go to my research site [here](https://yinscapital.com/research/) and click on "Buy Signal from Limit Theorem".)

# %%
start_date = '2010-01-01'
end_date   = '2020-01-01'
ticker = 'AAPL'
temp = YinsMM.YinsTimer(start_date, end_date, ticker, figsize=(6,3), verbose=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# ----------------------------------------------------------------------------------------------------
# Optimal Portfolio has the following information:
# Return=0.0011 and Volatility=0.0162
# Tail of resulting table:             Signal
# Date
# 2019-12-24     0.0
# 2019-12-26     0.0
# 2019-12-27     0.0
# 2019-12-30     0.0
# 2019-12-31     0.0
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# Once the code finishes running, we can start to print the result by looking at basic statistics such as expected return and risk.

# %%
print(f'Ticker: {ticker}')
print(f"Expted Return: {temp['estimatedReturn']}")
print(f"Expted Return: {temp['estimatedRisk']}")
# Out:
# Ticker: AAPL
# Expted Return: 0.0010870239090302965
# Expted Return: 0.01621671570824446

# %% [markdown]
# ### Further Exploration of Company's Profile
#
# If one wants to explore more, one can access 'ALL_DATA' which is a big dictionary stored rest available data downloaded from "yfinance" library.

# %%
ALL_DATA = temp['ALL_DATA']

# %%
print(f"Business Summary: {ALL_DATA['get stock info']['longBusinessSummary']}")
# Out:
# Business Summary: Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. It also sells various related services. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, HomePod, iPod touch, and other Apple-branded and third-party accessories. It also provides digital content stores and streaming services; AppleCare support services; and iCloud, a cloud service, which stores music, photos, contacts, calendars, mail, documents, and others. In addition, the company offers various service, such as Apple Arcade, a game subscription service; Apple Card, a co-branded credit card; Apple News+, a subscription news and magazine service; and Apple Pay, a cashless payment service, as well as licenses its intellectual property, and provides other related services. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It sells and delivers third-party applications for its products through the App Store, Mac App Store, and Watch App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1977 and is headquartered in Cupertino, California.

# %%
ALL_DATA['show financials']
# Out:
# [                                         2019-09-28   2018-09-29   2017-09-30  \
#  Cost Of Revenue                         1.61782e+11  1.63756e+11  1.41048e+11
#  Discontinued Operations                        None         None         None
#  Ebit                                      6.393e+10   7.0898e+10   6.1344e+10
#  Effect Of Accounting Charges                   None         None         None
#  Extraordinary Items                            None         None         None
#  Gross Profit                             9.8392e+10  1.01839e+11   8.8186e+10
#  Income Before Tax                        6.5737e+10   7.2903e+10   6.4089e+10
#  Income Tax Expense                       1.0481e+10   1.3372e+10   1.5738e+10
#  Interest Expense                         -3.576e+09    -3.24e+09   -2.323e+09
#  Minority Interest                              None         None         None
#  Net Income                               5.5256e+10   5.9531e+10   4.8351e+10
#  Net Income Applicable To Common Shares   5.5256e+10   5.9531e+10   4.8351e+10
#  Net Income From Continuing Ops           5.5256e+10   5.9531e+10   4.8351e+10
#  Non Recurring                                  None         None         None
#  Operating Income                          6.393e+10   7.0898e+10   6.1344e+10
#  Other Items                                    None         None         None
#  Other Operating Expenses                       None         None         None
#  Research Development                     1.6217e+10   1.4236e+10   1.1581e+10
#  Selling General Administrative           1.8245e+10   1.6705e+10   1.5261e+10
#  Total Operating Expenses                1.96244e+11  1.94697e+11   1.6789e+11
#  Total Other Income Expense Net            1.807e+09    2.005e+09    2.745e+09
#  Total Revenue                           2.60174e+11  2.65595e+11  2.29234e+11
#
#                                           2016-09-24
#  Cost Of Revenue                         1.31376e+11
#  Discontinued Operations                        None
#  Ebit                                     6.0024e+10
#  Effect Of Accounting Charges                   None
#  Extraordinary Items                            None
#  Gross Profit                             8.4263e+10
#  Income Before Tax                        6.1372e+10
#  Income Tax Expense                       1.5685e+10
#  Interest Expense                         -1.456e+09
#  Minority Interest                              None
#  Net Income                               4.5687e+10
#  Net Income Applicable To Common Shares   4.5687e+10
#  Net Income From Continuing Ops           4.5687e+10
#  Non Recurring                                  None
#  Operating Income                         6.0024e+10
#  Other Items                                    None
#  Other Operating Expenses                       None
#  Research Development                     1.0045e+10
#  Selling General Administrative           1.4194e+10
#  Total Operating Expenses                1.55615e+11
#  Total Other Income Expense Net            1.348e+09
#  Total Revenue                           2.15639e+11  ,
#                                          2019-09-28  2019-06-29  2019-03-30  \
#  Cost Of Revenue                         3.9727e+10  3.3582e+10  3.6194e+10
#  Discontinued Operations                       None        None        None
#  Ebit                                    1.5625e+10  1.1544e+10  1.3415e+10
#  Effect Of Accounting Charges                  None        None        None
#  Extraordinary Items                           None        None        None
#  Gross Profit                            2.4313e+10  2.0227e+10  2.1821e+10
#  Income Before Tax                       1.6127e+10  1.1911e+10  1.3793e+10
#  Income Tax Expense                       2.441e+09   1.867e+09   2.232e+09
#  Interest Expense                          -8.1e+08   -8.66e+08   -1.01e+09
#  Minority Interest                             None        None        None
#  Net Income                              1.3686e+10  1.0044e+10  1.1561e+10
#  Net Income Applicable To Common Shares  1.3686e+10  1.0044e+10  1.1561e+10
#  Net Income From Continuing Ops          1.3686e+10  1.0044e+10  1.1561e+10
#  Non Recurring                                 None        None        None
#  Operating Income                        1.5625e+10  1.1544e+10  1.3415e+10
#  Other Items                                   None        None        None
#  Other Operating Expenses                      None        None        None
#  Research Development                      4.11e+09   4.257e+09   3.948e+09
#  Selling General Administrative           4.578e+09   4.426e+09   4.458e+09
#  Total Operating Expenses                4.8415e+10  4.2265e+10    4.46e+10
#  Total Other Income Expense Net            5.02e+08    3.67e+08    3.78e+08
#  Total Revenue                            6.404e+10  5.3809e+10  5.8015e+10
#
#                                          2018-12-29
#  Cost Of Revenue                         5.2279e+10
#  Discontinued Operations                       None
#  Ebit                                    2.3346e+10
#  Effect Of Accounting Charges                  None
#  Extraordinary Items                           None
#  Gross Profit                            3.2031e+10
#  Income Before Tax                       2.3906e+10
#  Income Tax Expense                       3.941e+09
#  Interest Expense                          -8.9e+08
#  Minority Interest                             None
#  Net Income                              1.9965e+10
#  Net Income Applicable To Common Shares  1.9965e+10
#  Net Income From Continuing Ops          1.9965e+10
#  Non Recurring                                 None
#  Operating Income                        2.3346e+10
#  Other Items                                   None
#  Other Operating Expenses                      None
#  Research Development                     3.902e+09
#  Selling General Administrative           4.783e+09
#  Total Operating Expenses                6.0964e+10
#  Total Other Income Expense Net             5.6e+08
#  Total Revenue                            8.431e+10  ]

# %%
ALL_DATA['show institutional holders']
# Out:
#                             Holder     Shares Date Reported   % Out  \
# 0       Vanguard Group, Inc. (The)  618132115    2019-09-29  0.0810
# 1                   Blackrock Inc.  511535245    2019-09-29  0.0671
# 2         State Street Corporation  313871742    2019-09-29  0.0411
# 3                         FMR, LLC  243240860    2019-09-29  0.0319
# 4    Price (T.Rowe) Associates Inc  189992179    2019-09-29  0.0249
# 5          Capital World Investors  180450388    2019-09-29  0.0237
# 6    Geode Capital Management, LLC  107630296    2019-09-29  0.0141
# 7  Capital International Investors   98941506    2019-09-29  0.0130
# 8                     Invesco Ltd.   94344480    2019-09-29  0.0124
# 9       Northern Trust Corporation   93284473    2019-09-29  0.0122
#
#          Value
# 0  85938907948
# 1  71118745112
# 2  43637588290
# 3  33817776765
# 4  26414612646
# 5  25088017443
# 6  14963840052
# 7  13755837579
# 8  13116713054
# 9  12969340281

# %%
ALL_DATA['show major holders']
# Out:
#         0                                      1
# 0   1.40%        % of Shares Held by All Insider
# 1  74.53%       % of Shares Held by Institutions
# 2  75.59%        % of Float Held by Institutions
# 3    4239  Number of Institutions Holding Shares
