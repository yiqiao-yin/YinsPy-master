# %% [markdown]
# # DEEP LEARNING: USING NLP TO CREATE NIETZSHE'S WRITING
#
# Example script to generate text from Nietzsche's writings. At least 20 epochs are required before the generated text starts sounding coherent. It is recommended to run this script on GPU, as recurrent networks are quite computationally intensive. If you try this script on new data, make sure your corpus has at least ~100k characters. ~1M is better.
#
# Source of this python notebook is referred to from [keras team github](https://github.com/keras-team/keras/blob/master/examples/lstm_text_generation.py).

# %%
'''
#Example script to generate text from Nietzsche's writings.
At least 20 epochs are required before the generated text
starts sounding coherent.
It is recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.
If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.
'''
# Out:
# "\n#Example script to generate text from Nietzsche's writings.\nAt least 20 epochs are required before the generated text\nstarts sounding coherent.\nIt is recommended to run this script on GPU, as recurrent\nnetworks are quite computationally intensive.\nIf you try this script on new data, make sure your corpus\nhas at least ~100k characters. ~1M is better.\n"

# %%
from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io
# Out:
# /usr/local/anaconda/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
path = get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower()
print('corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 0us/step
# corpus length: 600893

# %%
chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# total chars: 57

# %%
# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 200285

# %%
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization...

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop()
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# Build model...
# WARNING:tensorflow:From /usr/local/anaconda/lib/python3.6/site-packages/keras/optimizers.py:757: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/anaconda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3014: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
# helper function to sample an index from a probability array
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
# function invoked at end of each epoch. Prints generated text.
def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
model.fit(x, y,
          batch_size=128,
          epochs=10,
          callbacks=[print_callback])
# Out:
# Epoch 1/10
# 200285/200285 [==============================] - 149s 742us/step - loss: 1.1119
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "ood! if there is a
# misunderstanding abou"
# ood! if there is a
# misunderstanding about the contented of the prociesting of the most spirituality of the process of the probably ambatter of presents, in the probabils of all, to the sense of the procieted spectes, the condition of the most spirituality of the contemptivic or their presently to the procietten can be almose the proble dobjess and despiaie in the probably ambeder more morality and self-destiles and despias they are not
# ----- diversity: 0.5
# ----- Generating with seed: "ood! if there is a
# misunderstanding abou"
# ood! if there is a
# misunderstanding about the domain of man. in the real power on the conscionce, the helps back we calls that the importunable the state of great is all astical state is the power of means and deligation as self-excessive and is thing not only the endigit of desire castes of which it is to seence of such agus and his own expedience to be emacitided intellectual desired for the prosses in its own spirit to among the same
# ----- diversity: 1.0
# ----- Generating with seed: "ood! if there is a
# misunderstanding abou"
# ood! if there is a
# misunderstanding about bet eabsay--when are power or others? he is a
# porure of errorbelity in us.  ho has
# colo hond-to us: "it is in realily be a sturhy defficult resuld that he
# careto alward naceles and attacuigate, awang onessiping) are
# volvine delusion that tean by makes idea, is orperability a body is philosophics hat glorifical prinity..--we deturnty for him cerseive one cas senses or morality is to highing of "i
# ----- diversity: 1.2
# ----- Generating with seed: "ood! if there is a
# misunderstanding abou"
# ood! if there is a
# misunderstanding about is some of much aths ciencesglatical natural,.."      ever doed not dear
# stingly beareyt with develousgre of servically resist an "sid.h uponunaroun daines.--that he may remare in who made
# knothhised.--stillfome cruised to so victrous presented about at long sairations, man with type from them, homoror
# only be thilk feclectly ordes form which man
# froms veicenttine overways
# profess, prepidivally.
# Epoch 2/10
# 200285/200285 [==============================] - 149s 742us/step - loss: 1.1100
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "rongest instincts they possessed, their "
# rongest instincts they possessed, their depectively the substated with the senses a dearly and so remankly little them there are despactively and often we every of samilations and love like the same that a philosopher and the sense of self individuals in the procision of the contrast is the specialers of the procie to the truth impulses of the most specialed of the possibility, and a such as a sincelity of his tainflent, and a such may
# ----- diversity: 0.5
# ----- Generating with seed: "rongest instincts they possessed, their "
# rongest instincts they possessed, their long ends. they not only such a sympathy, and his fellow whether blen with their sense in the same agroest induse the "psicssesming," of society on the highest believed to the heart of the contrast. the forement of the conception of the viction of the stage in itsed and distrust experiences in the possibility, the world of
# man always be resented a self desciented to self intellect, the only which
# ----- diversity: 1.0
# ----- Generating with seed: "rongest instincts they possessed, their "
# rongest instincts they possessed, their subject, there
# even apprehinity they askiours to the good
# naived. this world finst others and inferior, and
# deceiration insablece, it operly the stal personative difference pleasance, than the eloss without ans surcounce when he hare
# still rorance in actions at the
# soul or view. , we quatien it bittery has geibaing
# producces
# defes un the of egains, herself that uncilless in involverally, with once
# ----- diversity: 1.2
# ----- Generating with seed: "rongest instincts they possessed, their "
# rongest instincts they possessed, their swep ton and dogractic putress. more, that come to
# momaty ocher
# were it
# is possibly the lives or is, somethiness of true mentgoical supposed is given more
# has as is
# that
# strid effect here, induceusenance--of purisposity right. the indreament in its
# ord,ousnessment"" and place-being hypotheses; nowadayless and the  wnoclly thre
# good becomes. how the roman my doest
# livel us vely, as is terced to liv
# Epoch 3/10
# 200285/200285 [==============================] - 147s 735us/step - loss: 1.1079
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "evil spirits wage war with varying
# fortu"
# evil spirits wage war with varying
# forture of the present the standard of all repultions, that it is a surprates of the conceptions of all reasons, the greater of all the same men, they were are not be the former masses of the world of man who has been some comprehension of the world of man and so that the prospection of the consequent of the world, and the constant itself in the subject of the same as short, the spirit, and the world o
# ----- diversity: 0.5
# ----- Generating with seed: "evil spirits wage war with varying
# fortu"
# evil spirits wage war with varying
# forture of the world of all thing in this pride not as the sense of the world, as a privils; one be wretely to require their beingness,
# and more as far as must fact he
# sless to the soul of reason to acking their loomers of woman and pain who lashes soperf to be taken is not alrows to himself, when they believe in the stand of superioming sicks and in the same properly profound self is most and set unde
# ----- diversity: 1.0
# ----- Generating with seed: "evil spirits wage war with varying
# fortu"
# evil spirits wage war with varying
# forturally be ination of life, which are of and yet german laights in this capection, the little had of desire nobled for the repult poichoss and as
# beotray-dures, that contedul of intertangly, more sucrection over inwounds
# hone been a their friech--have everything its first thought--for an they with it. the conscience do
# dotanalist aids as the "other
# "gecolre
# spelite their
# other maintering, musself to
# ----- diversity: 1.2
# ----- Generating with seed: "evil spirits wage war with varying
# fortu"
# evil spirits wage war with varying
# fortuness,
# powerful; gually
# colrar will notions, in doicinity, so keallroes not
# the funch alroor asmowe or onerage
# to its virtues, idealiy imbelint and drenstruce
# scholenwerned and powers
# [a3] neirgism, also,
# what ! on the diskand pais, that a philosoph still against and laptian
# ly; which so that good vani, god as it with a constonent miskence
# severity, this his period
# preasch must whest they he hunta
# Epoch 4/10
# 200285/200285 [==============================] - 147s 734us/step - loss: 1.1055
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "s when
# judged close at hand, into which,"
# s when
# judged close at hand, into which, as a problem is there is all the substable not the formally canness and head, to suffering interpreted to the foundan and sense, as a problem is there is all the same as the spirit to be in his delight in the sense of a surposion of all the contoker is not the contemptive of a condition of the subception of the substable soul of the "good conscience, and despical of the substabaugusuld, and all t
# ----- diversity: 0.5
# ----- Generating with seed: "s when
# judged close at hand, into which,"
# s when
# judged close at hand, into which, as a propornce stord, there is not be precise as the world of conception, therebord and subtless and an and strong as the towards the word of the subject of the substable to like the science distrust.
#
#
# 11
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "s when
# judged close at hand, into which,"
# s when
# judged close at hand, into which, who frot vear tyo-recocuds.--so the old feeling and assuthered of artistic istent to them? that
# there
# are defthrice its eyes appear. ence anound for i should
# alw overware stor. things yee.
# this sensived at the sensable must yet the extentle of dreamsing of the termive which like the express of creation of a glory fring and invidial is to sugh a commolaty is dogeness, uncosedable notice. socifine
# ----- diversity: 1.2
# ----- Generating with seed: "s when
# judged close at hand, into which,"
# s when
# judged close at hand, into which, when to takes by as pragacial great
# stility and
# sears do by mod end resuliegest; but with its nobles.n
# is false anway
# to his "sincestant and no
# leasm," by the presine mannershing, however, all reshitifice could when they tates stold, canatily sensibly
# for im no soll, to an excessive occases and their conducism as the polute, of
# our pleasure, morals of
# sobjaceme: is as kun-sending the
# abtumndeled
# Epoch 5/10
# 200285/200285 [==============================] - 148s 737us/step - loss: 1.1036
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "kers dare not oppose such
# disinterestedn"
# kers dare not oppose such
# disinterestedness and any the subject of a condition of the presented which is called be the diseinces of the proceed in the present drop of the presently the same mankind and is the world of all the same thing of the present dissing, and deducion to the present is a surprised and the procees of means and presented to the subject of the present dring is the such a sirgrow, and the constant of the present dissin
# ----- diversity: 0.5
# ----- Generating with seed: "kers dare not oppose such
# disinterestedn"
# kers dare not oppose such
# disinterestedness of the presenterwation think of the laws and discovered and developmed and dread-monly, and part the sense of one who laughe be the dema prourbly the same mankind to the maining is the present is the more reason
# and cruelty of the fact to
# the "latter", with its obsidement, and the same with fact, that is the standing is
# connecter that the old
# thesergous sense is a time to the origin and an act
# ----- diversity: 1.0
# ----- Generating with seed: "kers dare not oppose such
# disinterestedn"
# kers dare not oppose such
# disinterestedness and destrogay and demot is
# as a carrived a
# feelings to purpose umbe
# a like
# the recidive opponable excession of the slack of life has not alavound that the partic men is moreptabli he cherem of althirmanary for thmourd painful, at all respection, a things by his longing age, there who passefulty. mind, more utermen and canity, in eeartyrary insaged and can conscintle: the sensainations _knowle.
# ----- diversity: 1.2
# ----- Generating with seed: "kers dare not oppose such
# disinterestedn"
# kers dare not oppose such
# disinterestedness for suct
# befot
# amys an eals are" i his taste, real as, and of at i is a prusenty--theuthis is manifest in a compalsofirable and sugh ban,s,
# no fixedness under more awrituation. yet
# his every more catem
# gileref, to disalofied as music blay, the consequences caste well know ut of the
# jewnom is is becies ary notwied.
# it foom of sense, as
# the unrortranous grain, it with regard to be into thing of
# Epoch 6/10
# 200285/200285 [==============================] - 148s 740us/step - loss: 1.1011
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "he great statesman, the conqueror, the d"
# he great statesman, the conqueror, the domain of the existence of mankind, that is to say, to be recoised to the philosophy of the world with the state of the truth is interpretations and despiacitiation of the present and disciplingnt of the herding, and there is not a deception of standards to the former and of the world of the restert of the world of plate in the state of the present dissive of the conception of the conception of the
# ----- diversity: 0.5
# ----- Generating with seed: "he great statesman, the conqueror, the d"
# he great statesman, the conqueror, the desiration of the process of the order of the strange the morality of the most free with his tapprded interrousness of the possession to its utility had a sole of discreminess of the world with which are not as a surgand the more of the valuable states of man is possible it be among the fact to the former which be are stoold been sensured is subjection, the really still also, the other another arti
# ----- diversity: 1.0
# ----- Generating with seed: "he great statesman, the conqueror, the d"
# he great statesman, the conqueror, the demon, why was as because up, ye men of slave-inlordy man is presented to distrest right: and always not sedience good hal, to kil of cosmulgence thinking, remankable.ually so, that
# a think any ascentual as
# marter this simple, so, an inding sourh laws exclose themselves!
#   that
# what it-seefitude. in according revers of woman, and are good to appar thus
# to religious manifests itself as an
# instrument
# ----- diversity: 1.2
# ----- Generating with seed: "he great statesman, the conqueror, the d"
# he great statesman, the conqueror, the domain
# and in-gvivalization, soct portikness--poweraledy ided to that under majeshy,
# slenk pursomy bickndane names, he--hews.
# concemptited causately of opdinabil
# "fory hal opigile esuctuals that
# as musecknonneds,
# regains! fathiop?
# unorarion inpovirately rena-oupder, and ampeetion occallting viousously spirit fover rage any believer and oftrintialque, radied to a possibility,
# many is; and honest wit
# Epoch 7/10
# 200285/200285 [==============================] - 149s 742us/step - loss: 1.0992
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "orthiest of respect. the way in which, o"
# orthiest of respect. the way in which, one former the contemptivication of the superstition the sense of the world of the subject of a certain and didgent of presently to the procisity and interistion of the sensable and every as the soul of the present dissimes the procisly reasons and the sensable and every as the subject, and the process of the world of the world of man histortations, and the world of man is all the sense of the most
# ----- diversity: 0.5
# ----- Generating with seed: "orthiest of respect. the way in which, o"
# orthiest of respect. the way in which, one say to the englishpe and destruct of all the costoming the subject, with this sense in the results
# of the fundamental inner of the early ider of the delusion of the secret of a perposents is the same time or world" to the fast to do preaculed preserved in the subject in inversed and perception, and the substable to self is is almost results is the spirit to be a surpre and of an error of the se
# ----- diversity: 1.0
# ----- Generating with seed: "orthiest of respect. the way in which, o"
# orthiest of respect. the way in which, on troub-do a the
# world. "fan is"pposhent," of worlds of strongarian--of even youth conceptable comrogical statedy in beaptith the most discrusted, and and often do lo
# my friends.--who all maors.
#
#
# phuehter a man wears nowandeverarness, in the development possible, perhaps of his doubcer of woman," at any hold in reparaply, that the taste a german brodaged. but everything is there glowe preatuless
# ----- diversity: 1.2
# ----- Generating with seed: "orthiest of respect. the way in which, o"
# orthiest of respect. the way in which, our -all
# question; and any things condition belooking is, we shave knows
# at tnellud everstance of train
# mare, anwind in diffessitic wish old doker not county
# , indeame you has and ever the eymint.
#
# for an accoid
# of ene, obvicable deviling of:ersrioc, the whole who in the any grave of dark,
#
#
# 11ho
# end well bur is, perhaps, and wordst pritth foolsway bown and more. the fastics of lease him sulfecdion
# Epoch 8/10
# 200285/200285 [==============================] - 151s 754us/step - loss: 1.0965
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "lave-morality is essentially the moralit"
# lave-morality is essentially the morality of the presenting the same men who say the contradicionate and and the longer of the world of the consequence of the herety cannot for head and every stronger man is the fact that the conception of the terming the state of the presention of the present the strength of a sirers of the problem of the existence of the sensestand noble manifications and more conscience, and of the particism and cons
# ----- diversity: 0.5
# ----- Generating with seed: "lave-morality is essentially the moralit"
# lave-morality is essentially the morality of all the same still man as still with the dear true for the end main yourfle, and who can lought even some ethics which has also how to demained to him. the demand of a costals carement, in the past of a surpicion, the religious this soul opporant of understand of his existence of one self and finally therefore, which has also the "present-man in the blood, the temptic constitucery and depusti
# ----- diversity: 1.0
# ----- Generating with seed: "lave-morality is essentially the moralit"
# lave-morality is essentially the morality of
# imstoblention hyeals
# athing its despective sensuthial german princesity, that venture,
# the small cutionally suf that is to implose the vilual even hot the instinct philosophers one emong a imaureation with morius, which transher fersust: the sure, the domianing is, we who has on
# tre perceaval, the eyernal
# your old, and of hold-canliness" is not honests the
# possition, this simple devolvend to
# ----- diversity: 1.2
# ----- Generating with seed: "lave-morality is essentially the moralit"
# lave-morality is essentially the morality of manbill begnes, siffuling
# two hearte in a "sould appear,"
#
#
#
# 8(
# if his miding higher art, without no othersher3 is also patisps oes so far imseim as madeance to this "catrest."
#
# 2isa, and of augoo
# the cann the eyon in the
# confects becommingly radials,
# they were acrivitly always oeltouded hitherto whate, the strength, and right" resposition our easirate the
# nature of the damerajoring, and reta
# Epoch 9/10
# 200285/200285 [==============================] - 149s 746us/step - loss: 1.0964
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "hings to prevail; men, not sufficiently "
# hings to prevail; men, not sufficiently blood; in the same of the subject of the senses as the same time and sentiment of the hereditarism and of the same miston: the highest bancinal patie and denge to the same mankind (or the world with which it is the subsiabation and existence of the heretions of the process of the same misunderstanding of the procision of the same misuntoranies, and and the sense of the world of god and instinctive
# ----- diversity: 0.5
# ----- Generating with seed: "hings to prevail; men, not sufficiently "
# hings to prevail; men, not sufficiently and appearansous strength, it is a procidly surversed and conceplieinives to metaphysical for far a sident and great standards to his course, that is to in him such man who passi- penhaps are religion with the same misuntinguled and first strive and longing is not the feeling of the same that and of the explanation of the importular musical prints and loves himself and distrust, the fact, have to
# ----- diversity: 1.0
# ----- Generating with seed: "hings to prevail; men, not sufficiently "
# hings to prevail; men, not sufficiently with degerations.--as so for the origination. thus, "the badk of growars that he chourt ming, their grow rigishoulg. undering the free with
# ecrogg and
# language in supping, is the great, he disestre, the heard--it is also the aniveratic
# models condubel."
#
# kwhacts is art streccip error hi
# heriesg. they laok
# firtle, beenomable, more e regathifican of the prosess of notinge and firstlagnouag,
# entaist;
# ----- diversity: 1.2
# ----- Generating with seed: "hings to prevail; men, not sufficiently "
# hings to prevail; men, not sufficiently without "be"-only scielness."
# bloss tognarous dangust grents, a
# bad come toghter. of have boer, he find the elivine
# tint eys creise which beake the poperansion
# canifilation, minstre, our evolst as shorm of and i ciriousnar, womlent or "modiedess-"assi alop, of humany, herhingrial effectaxce.
#
# 11xtesc geration: "i mo; looks.. what, if being humanity.
#
# 1ue, cannceron grable
# senknated to knows-to un
# Epoch 10/10
# 200285/200285 [==============================] - 148s 741us/step - loss: 1.0928
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "--secure to make!"
#
# 141. the belly is th"
# --secure to make!"
#
# 141. the belly is the problem of the senses as the most speensory and painful in the sense of the world is as the world which has the personal really conscience that the sensable to the any or all the religious sense is a surgains and despice the substable not secret of can be so thinking is not in the possesses of the most such a profound in itself, there is an allents of the sense of the most speaking of the concep
# ----- diversity: 0.5
# ----- Generating with seed: "--secure to make!"
#
# 141. the belly is th"
# --secure to make!"
#
# 141. the belly is the problem of the world is the infinior of all life. therein is so tone, and in the conception of the subject of the senses of the german stands to be would have been intellectual discredities which seems to the condition of the most speaking, of the herdition is only as the whole lights the same at a consciousness of the sensainess of the long laws of the concemplat time of
# the last enoughten and
# ----- diversity: 1.0
# ----- Generating with seed: "--secure to make!"
#
# 141. the belly is th"
# --secure to make!"
#
# 141. the belly is the gured
# to concewnly
# dangersfor, roverable flows of mangers: there assign to worthers can rorard, emocingghting, or uside: we can of christian god
# and anceonsic, the unitee, as a bad conceplesing protect of the soul only delight incentivive
# sense. the suby thinking of all the seeming earneless, simply,
# such
# as to it, without man weaker that never youth magak we have in the one has run
# getualing, b
# ----- diversity: 1.2
# ----- Generating with seed: "--secure to make!"
#
# 141. the belly is th"
# --secure to make!"
#
# 141. the belly is the impotulues mass; all and to say. his of his philosophy a bittom or himself that ears, betifenes ghing; the tasel in
# his only to
# the fild contemsion is to the greatest state of reality itself is more theiving of being. in fact,--nated. outwerance, was thus wayshing the elose which changerin re, regath to which ye mandula.
# in about they extendes, that out hour, in beon"s!" yoo
# therefy first of his

# %% [markdown]
# Investigation ends here.
