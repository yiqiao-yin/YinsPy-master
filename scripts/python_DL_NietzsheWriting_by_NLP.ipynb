# %% [markdown]
# # DEEP LEARNING: USING NLP TO CREATE NIETZSHE'S WRITING
#
# Example script to generate text from Nietzsche's writings. At least 20 epochs are required before the generated text starts sounding coherent. It is recommended to run this script on GPU, as recurrent networks are quite computationally intensive. If you try this script on new data, make sure your corpus has at least ~100k characters. ~1M is better.
#
# Source of this python notebook is referred to from [keras team github](https://github.com/keras-team/keras/blob/master/examples/lstm_text_generation.py).

# %%
'''
#Example script to generate text from Nietzsche's writings.
At least 20 epochs are required before the generated text
starts sounding coherent.
It is recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.
If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.
'''
# Out:
# "\n#Example script to generate text from Nietzsche's writings.\nAt least 20 epochs are required before the generated text\nstarts sounding coherent.\nIt is recommended to run this script on GPU, as recurrent\nnetworks are quite computationally intensive.\nIf you try this script on new data, make sure your corpus\nhas at least ~100k characters. ~1M is better.\n"

# %%
from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io
# Out:
# /usr/local/anaconda/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
path = get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower()
print('corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 0us/step
# corpus length: 600893

# %%
chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# total chars: 57

# %%
# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 200285

# %%
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization...

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop()
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# Build model...
# WARNING:tensorflow:From /usr/local/anaconda/lib/python3.6/site-packages/keras/optimizers.py:757: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/anaconda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3014: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
# helper function to sample an index from a probability array
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
# function invoked at end of each epoch. Prints generated text.
def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
model.fit(x, y,
          batch_size=128,
          epochs=60,
          callbacks=[print_callback])
# Out:
# WARNING:tensorflow:From /usr/local/anaconda/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/anaconda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:977: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# Epoch 1/60
# 200285/200285 [==============================] - 146s 731us/step - loss: 2.5064
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "penly anti-christian,
# although (for keen"
# penly anti-christian,
# although (for keen the mere the sente the the serente the the the the the the the the the porente the rent on the the seres and the ine the sere the preresting the sere the sere wo the the the sere the sere the core the the the the the seres of the the the sere the sore and and and and and the the the the the presting in the the the seresting the the the sure the wing the the the sere the serentit and and and the t
# ----- diversity: 0.5
# ----- Generating with seed: "penly anti-christian,
# although (for keen"
# penly anti-christian,
# although (for keen the be the welnate the forted the the hand the hor han the ars on serent of or the ingend and inting and bime thit dithe fith, the mored the  as the sersing ind is in soul the seler the as al ande the the sonathe the prite the mest on the sore in and ane the ghean in the sertinte no hing the bencind whe the grtingor be the the hat in the this and and which and and and and the derere the pithor th
# ----- diversity: 1.0
# ----- Generating with seed: "penly anti-christian,
# although (for keen"
# penly anti-christian,
# although (for keen cionl us o sinithit than perplorth facl gied atitin oulhs cat in and, susd in woree in antmtn creanting
# rfong. lh ss ogsurses ins insoll toucterd, ol,, wes irs, batt in the ingel sis the prpucaly;--goren mand ung trew the ocrtrese vopies don whentat ageruthdudt weluthe.
#  meks meligcoly,
# ghled in le kre akgo prith if couse tro with uns in menteod .
# e. t-ter to the d hith bedin iirims aide-aliledig
# ----- diversity: 1.2
# ----- Generating with seed: "penly anti-christian,
# although (for keen"
# penly anti-christian,
# although (for keengt is edrgretine! ivestof cr,nng yhe pnwuits is forite"t tan a torasely wiligeyv.
# fukle int licguin tiche them; c, mol sonqteat
# ti t everaha-stong, in cherten ingly. hamlepu---whromthety wther
# aypperlaswucincpeut ttue nesing frove nhiny ant. ond copeat-ot ts fel dyrect is th. treactty
# sicdict
# ti dongite tto
# ghian n sistlofgrint
# a foge poas wis mint
# tsenoy ho: hok " eveusi"gf"ins
# mere if we the mpe
# Epoch 2/60
# 200285/200285 [==============================] - 146s 729us/step - loss: 2.1126
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "ste. she is unlearning to fear man: but "
# ste. she is unlearning to fear man: but in the soull the mont and in the pronother of the erean sence the mone the warl of the preastion of the mone sencers and indertion of the intertion of the propestion of the manter and the sencersed and and the mantion of the prother the preast of the sored in the more the ereate the manter the serent of the prostion of the sonder of the prowing of the preanter and the menting and and and and and a
# ----- diversity: 0.5
# ----- Generating with seed: "ste. she is unlearning to fear man: but "
# ste. she is unlearning to fear man: but perees we the man is the mares lot the disters, and manter and whechen the man alligituon ender and to will and woll the for the ore thing the mencen an the firen as a with a poren which one sound and and inselficce se the garther sat hat in the mane so the han the propotion mons which the preanted the promest of consece, the manther and eneas in the nowing of ald in orouther as a wall he perounte
# ----- diversity: 1.0
# ----- Generating with seed: "ste. she is unlearning to fear man: but "
# ste. she is unlearning to fear man: but themres
# pradefuvist, and villtes to ulsudics pelogs withe
# siysive, and theriento! it notwerpere. the
# .
# pvinitity
# and
# enticanite stifes hes ously wuel, concetsuch fern
# what mace
# xand met in ultdring, cunting) of wasmerat
#
#
#
# .
# =sinfying in so ctualt in ond
# inmandy in olr gainy, that meseecs
# rigit, whith uexersings mat therem ead hendeabtry the wich is rocale po aldhist, that ona avecn the pingre ove
# ----- diversity: 1.2
# ----- Generating with seed: "ste. she is unlearning to fear man: but "
# ste. she is unlearning to fear man: but bope, thuwhist haw
# regvowhat
# ?e
# indyifxcuktura to mangime is re bitte us at art whints?
# mur: hintsehing, quefede he firmerduas the porpressyef! brome olig, preadly porne, rnecumuth of harialm, wthe htequitutaof enut ty tha stithn"eg esdists, hagevevenare, int oorcaowing geatorling.--gher hereden forcon-)lesemtoirar, shough, theass.? tho gfistius fqo iiter thictir dngrutt oul sene-co
# sactiol furous
# Epoch 3/60
# 200285/200285 [==============================] - 145s 726us/step - loss: 1.9527
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: " il contemple les
# choses d'une maniere d"
#  il contemple les
# choses d'une maniere deaply and and in the soment of the senfice that the senting of the conterting to the sencention of the senficion of the semplopestion of the sich and and and and and and the stinct of the senfice the man and and and and and and and and and and and and and and and the senger of the senfertion of the senfice the resting of the senficion and the somenter and the senfice to the simpromanion of the sen
# ----- diversity: 0.5
# ----- Generating with seed: " il contemple les
# choses d'une maniere d"
#  il contemple les
# choses d'une maniere deaps that the
# moning of himself thes mentlous, the his ane the condenterans things and spilitically compration on the possinity of the furtion of theseng touth wo to ploust and and montimalis of
# condicient sich in and the entint of congertion of the antire and of the recention of the prostict, and and and manting
# to the east of the raster to what perination that the still and gonelope for han the
# ----- diversity: 1.0
# ----- Generating with seed: " il contemple les
# choses d'une maniere d"
#  il contemple les
# choses d'une maniere demally wo it fyinkd, pecting--buct ofll wio
# though thully tomse.ve cance
# hen.ewhing on raless it is
# fort pospuroument ham as efides whehad indearus llathans
# ow inmorit--in-lipting for benid eving but it find. but mastols is risting alittemctous of theauls whloum, andverend our our the beast of
# remplendess humandaly somperded and prealing this
# devie ment or hol
# thats act a t menter.. thate the utou
# ----- diversity: 1.2
# ----- Generating with seed: " il contemple les
# choses d'une maniere d"
#  il contemple les
# choses d'une maniere diseblanss coltienon,, tome cail andare
# conditids. "fithes ppiscimentionty nowewain" osperains! arlysthan that peilurely,--enallucgcoca torste. man a lays lefem an orgertioned
# netatidn mastends
# ormiatly cortachirsstos, utrlivids werenc. them
# a sunionary veains to one orngroused of eving is exciinconck of thotewispowion, piedect a mage arfcimess and
# wistly, feelon, apoun tamercelly becthanwion of in
# Epoch 4/60
# 200285/200285 [==============================] - 145s 726us/step - loss: 1.8452
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "ot in
# accordance with usage, to oppose t"
# ot in
# accordance with usage, to oppose the consersed and the contranty the self compreation of the consented and the self and the self and itself the self in the such and and the sention of the concestions of the sention of the consertion of the contrations of the portion of the concestion of the more the some in the condering in the man in the condering every in the contran in the present of the self in the man and as a self condeman o
# ----- diversity: 0.5
# ----- Generating with seed: "ot in
# accordance with usage, to oppose t"
# ot in
# accordance with usage, to oppose the sorien under the man in a of the cantion of all and for the love of the soure in the comention of his concemsed to the mantand the dowerd as the sore the expare under and preased and eradical the action and experention and every man it esture of more very more desires and section of the consicule this hit the superain man every the contrands the faness of the love in the more may and in the dis
# ----- diversity: 1.0
# ----- Generating with seed: "ot in
# accordance with usage, to oppose t"
# ot in
# accordance with usage, to oppose thigge simplacisp areans sinselment, the is caist and as arguinarls resundermand nofilual the welf to to motalianisfalico,, and hame finding, an allofice, vartion, good of cuslidions mincer,
# nobliven as frow to is to sey, and
# exofpenercred-annach the exhisshasing to strotions
# woold consible and wilidry mastyo, and stertapceps, it is a in fich dimulorily to inteling campe sace manay,
# as ints, one-!u
# ----- diversity: 1.2
# ----- Generating with seed: "ot in
# accordance with usage, to oppose t"
# ot in
# accordance with usage, to oppose this."
#
# 219. he dectorul off this pent
# sondrhess
# oy so ightakns, peorerybuse, segised in laged ttouls the eremivea.te: agking wy muke comantly ayss, wpol, that "ffonetadiang of momal!
# aselquestan stemctiry,
# litess. suces--evilucy, suedernot
# condxcemplysquliee. ?
# 'bledapaly is herepted," comican theursevusth it.
# inchishicgt hover
# an, whend a -tui taina excompadias condidgs so urfials, promby ho his
#
# Epoch 5/60
# 200285/200285 [==============================] - 146s 729us/step - loss: 1.7635
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "mense and
# wonderful task, in the carryin"
# mense and
# wonderful task, in the carrying and and the strenger the whole the strenger of the strenger of the still to the the the standing and a the some the whole the self the concention of the sumperses and the the soul of the supperses and the self the contration of the still to the world the constinct of the strenger the such a precistion of the strenger the such a preass of the strenger the strenger to the the strenger in the stren
# ----- diversity: 0.5
# ----- Generating with seed: "mense and
# wonderful task, in the carryin"
# mense and
# wonderful task, in the carrying and and a master to the moraliced to deet to the would and a proses of the prates of not in such an the self of the posticion of the outher or that in the mister to the the prost of the forme of the may hand will not the true centual is that the present the had of the will of the deprepsion of a the contres to the contrity and distrate the contrate the to made one and some that the stily to the
# ----- diversity: 1.0
# ----- Generating with seed: "mense and
# wonderful task, in the carryin"
# mense and
# wonderful task, in the carrying a meatry and inceritiont
# manerle, shie veryopty not
# knowlerged of the utejution, in the challe ot wicl
# frhilives such a bid
# conved
# being--a ther "tro upheropher, a norre
# shather
# casserst--surtation we ham him only wipre the sinfulained to suckon.
#  en indees, or art his lueth
# lsough desironce of rewittre, nowuth emedoor the unolution the
# tinto any aptify and everyob
# the consencate
# desirious of pe
# ----- diversity: 1.2
# ----- Generating with seed: "mense and
# wonderful task, in the carryin"
# mense and
# wonderful task, in the carryinalisy sucrer. the
# corpersedvations ones.m han srificless
# are almo the ttran scous
# of unveent aborour tysth(mrany in
# oflive and notmon porpt bagseany diviluicruad is the pejest with howedgr thewedit "truad
# whold"rbyce to thes man and this fill--oodne the meer lots it scakeals eviringpising rage, sual
# dost us nate,
#  h an." owe to be.
#
#
# v5yhan "to men supuridution and
# tourle, thit dominrangi. to the
# Epoch 6/60
# 200285/200285 [==============================] - 145s 724us/step - loss: 1.7010
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "cessarily
# suffer, and is meant to suffer"
# cessarily
# suffer, and is meant to suffering and the contrance of the contrance of the present and the self--and the mean of the sumpers of the self-called the concemsion of the contration of and the such and the conserse the concersion of the self--and the contrance of the self-consice the contrain and the concemsion of the will for the concerness of the self--the care of the recerding the master of the contrain and the conscience to th
# ----- diversity: 0.5
# ----- Generating with seed: "cessarily
# suffer, and is meant to suffer"
# cessarily
# suffer, and is meant to suffer the others or all the
# world man for a self--in one in the ond the uncersarion of the persoppes the concemsed and the prosention of and the interserting and sthing which is the condinition of expection, and the merion and secess of the self-sheems in the conscience to the cancesed in one the reight in the to the then we latinate the seess be inderstrang, the becture canser and deservent such not a
# ----- diversity: 1.0
# ----- Generating with seed: "cessarily
# suffer, and is meant to suffer"
# cessarily
# suffer, and is meant to suffer would lefdken were a pery--and it is ghe say dbeish re, obking, fanger one in, therewial asout commant; do se
# being byict belourd to the capere of scample, what is morely and factunely of a hepedues the commonality phishsimy itself,
# byichn enely in the morally gan on exical bean in he has man alow
# men it expentable--but bethaid deringint, mects of fimeguratices to the condincuments of "this with
# ----- diversity: 1.2
# ----- Generating with seed: "cessarily
# suffer, and is meant to suffer"
# cessarily
# suffer, and is meant to suffernest grean empecteicr) if
# caner"--evil als and welf-seiri,
# for
# hond, haw life orstittin: seilis, otsoutd, id ligsces to vair, all theremouding, speking giving."
# mued which bicred
# the mutich tumse vainentive, there
# cart natured adios of virtion is lackingtibll marss, to of mading canive aim gre-parers, in preveduated,
# merep, one more bes, chared"--which a mancenationation.
#
# 2g5aity, (and that by no
# Epoch 7/60
# 200285/200285 [==============================] - 145s 726us/step - loss: 1.6503
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "true merely because
# it makes people happ"
# true merely because
# it makes people happering the more of all the consequently from the for a self the more of the one and the ond all the world of the for the most streng in the constinct of the one which is a such a prodicity of the soul of a consention of the contrang the self indering all the expersence of the contray of the one which is the for all the world of the world in the selfation of the subelity of the religion of a such a
# ----- diversity: 0.5
# ----- Generating with seed: "true merely because
# it makes people happ"
# true merely because
# it makes people happerate of consequently of semphrais, and incounder the most secuation of must the grodicion of appolit and soness of the mone the most and are and all the old of
# the expection of the ond who good in the order the wolld of the
# powint is the most disince of the compleation of conduct of the expenience pread and all the order the most speriation and evil as a madust
# the mose for his concertions and ge
# ----- diversity: 1.0
# ----- Generating with seed: "true merely because
# it makes people happ"
# true merely because
# it makes people happesed and his we fay editnount-doed becemance with who would for consengence of tases in the appeoos of wiskeriniturs,. thele fiver be is full of deess of is the
# enviry ffreate of acrow. gon; ain to wishes, belomous aname if whyn yow the donger it, havenge have, by not pherioy who ereserigitnesserful, it is eurigian but farte and hild of feellows, the carnur by
# stills for eventing would ove, bhis s
# ----- diversity: 1.2
# ----- Generating with seed: "true merely because
# it makes people happ"
# true merely because
# it makes people happor. buturice of every ovenly deitkels bee! vain and  ure overgors efor, anstuhi?
# deriegf the will be
# possistusapt, tery fod a teatity of leecling headtry an inmration
# of this modentyes duppress: in reca,ly psopettor,
# drean with gead, but of fiviraty ins. the life.h whal hemsend other headner cracee whuch the reach, rustnaies), acls
# onl aibagions, was
# turbed--they "geemp. ques,
# hemal thungs
# geashe,
# Epoch 8/60
# 200285/200285 [==============================] - 145s 726us/step - loss: 1.6081
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: " the whole of christo-european
# morality-"
#  the whole of christo-european
# morality--the man is also a reading and something the self-consequently and the soul and the self-consintly the self-that is all the self-consequently the self-that he cousted the self--the proson and the same of all the self-consequently the self-consequently and the self-that is the self-consequently the same that is an and the stronger in the self-consequently and the stand and the self-consequently the
# ----- diversity: 0.5
# ----- Generating with seed: " the whole of christo-european
# morality-"
#  the whole of christo-european
# morality--and the grotical shall as the artions of all the self-tained who has not it really been the obverted to its something is
# contemptands of strenger in the pread and truading the desire that the strengly with the will to the earthers instranging that is not the grod
# complesention of the erplesent intather of the subsentances of the sear of all the canest of the our power of the self--readons in the
# ----- diversity: 1.0
# ----- Generating with seed: " the whole of christo-european
# morality-"
#  the whole of christo-european
# morality--to instand
# and
# might, high order to the hemilation ot profurge to life-mithroure is caluse as seneest almiscustathes
# nature
# more oundrood, and greatest than actable a modalind of which hond us the thus that as a religions of instance nongemtanted that we all tradared take; and selced sobaristy opicion it and greated are
# the erowes other one that as roself
# inttentiously that
# heround, that the call
# ----- diversity: 1.2
# ----- Generating with seed: " the whole of christo-european
# morality-"
#  the whole of christo-european
# morality-shound-destronfoly is to lowind, folly a ling auph fact crecored.
# butty, it wis god
# trouble
# oble indoduance has nota, trunk. which ear,
# sierst."
# 1eehy ary to mon oughem.s.  and wast, himagerany hird epided meaninge: not
# to manist, that ill stromencl that, and to beutts transcasess of had amof cattres.
# gpeome. woll, a2men, a stranfabyy,. ta heve same. me,
# idageant as comeanaledeyc, theose dishived
# Epoch 9/60
# 200285/200285 [==============================] - 145s 724us/step - loss: 1.5721
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "conscience to rest.
# we all feel, when th"
# conscience to rest.
# we all feel, when the sermation of the self in the sumporition of the sense of the strange of the sense of the self indering and the strenger of the sense of the contrain of the self in the sense of the strenger of the sense of the strenger of the stranghy of the strenger of the subjection of the sense of the subjection of the sention of the sense and every of the sense of the sension of the sension of the subject of
# ----- diversity: 0.5
# ----- Generating with seed: "conscience to rest.
# we all feel, when th"
# conscience to rest.
# we all feel, when the restraction of a self-certains, as in the groman of virtues, and well for the strands, and the more is all the compresent for the precision of the sairific with its more subjection of religious procistion of sick for its spirit of his desire and which is his perhaps the
# contrays to the entical still process--powling the spirit to the recention of the art of the denient the spirit of the deminthe
# ----- diversity: 1.0
# ----- Generating with seed: "conscience to rest.
# we all feel, when th"
# conscience to rest.
# we all feel, when thinking also more abitual infelitunes and dusically knoblemany louffilm unjortary and beling of all shope sfichous whoochen leard a phoole sim: for the need taken now beryes  the is an andary, world and everything with requict--monerriog. the condicion required than anise fineriaked to aray itself reshrourly christis are har of vilrar, as an he well hand we knowlowen that he pitsle over the same of
# ----- diversity: 1.2
# ----- Generating with seed: "conscience to rest.
# we all feel, when th"
# conscience to rest.
# we all feel, when the gruingrallym, with itter!s--the same nomeestarines generstish peasons in ooder us corsants his, that is
# aurtathation ffor once this is mack and frvelo-)uch. they regerman
# lights, woulds
# rezarnel, it--outhing." has neevestiest upon
# ething uaw hadd masy behimdennaded yetwerod--than in
# werely lowe vaibly dies.nal, such fil--is willphas, greopmed paron, ancists! "hab"
# exceptiam, hrdainemole, through
# Epoch 10/60
# 200285/200285 [==============================] - 145s 724us/step - loss: 1.5407
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "form--his
# ill-will to the young frederic"
# form--his
# ill-will to the young frederic is all the present the subel and present and every and all the suble the endicers of the interpretations of the standard of the subelation of the same of the moral of the sense of all the self-considerations of the self-conscience and has also the strenger of the expersence of the self-conscience of the self-concems have the strenger the sense of the present and the subely and all the sance of th
# ----- diversity: 0.5
# ----- Generating with seed: "form--his
# ill-will to the young frederic"
# form--his
# ill-will to the young frederic becience of every destraint as the same of life and self-called in the sense in of all the eneigrating of cirture is culture, world and he has even to the becture of all things and the same of the such a things are the self-conscience of such a the arting some for the contempt of the paint of ears, the conscience and all the soul of all who in the endicate in its ortal is live in its sperits of t
# ----- diversity: 1.0
# ----- Generating with seed: "form--his
# ill-will to the young frederic"
# form--his
# ill-will to the young fredericuction for
# fecienove new to as imparty of all time into outs restautum, in artibat himself
# vany man this farms, such man, it impentained side) to fave
# onough ssiences and circle sight,
# the presens alaintates storsion blows
# in the intimull tersobred epilicilus at marn that it is
# slass to the finds orly and proberous sethentation.
#
#
# vialetys
# ss becalod, the ssels,
# have the cooragiest etoly recenditi
# ----- diversity: 1.2
# ----- Generating with seed: "form--his
# ill-will to the young frederic"
# form--his
# ill-will to the young fredericit furm. wo anligit as, notaremt that to be elach prosonital-dislingous bypable, hopoun expresse or gridual, wothticiant
# sausfanization, adour and head to easo:
#  goes its recelnset erten of the vost of charisoty, three esponction often ears and cotrea
# natoingment in the extent-dithrem ;tater-and himven vanure one for
# then,
# i philosophy or yee; in renes ranizing itsidg and
# socrot
# also the greal
# fai
# Epoch 11/60
# 200285/200285 [==============================] - 145s 725us/step - loss: 1.5118
#
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "elf annihilation? i believe the deciding"
# elf annihilation? i believe the deciding the held of the more of an any conscience the great and the subtlest and the consequently the subclent of the sense of the experience of the suble the sense of the experience of the self-concemsions of the subelation of the internation of the interlect of a prose that is the self-calused to the one the most sacrity of the subclent and contention of the moral of an any conscience the subelous and
# ----- diversity: 0.5
# ----- Generating with seed: "elf annihilation? i believe the deciding"
# elf annihilation? i believe the deciding to are of the self-contempting with the whill be entimely the lower the contrained or and believes and determent, and the enders and intersoretion of conception of supprited and of as the most the and according to the internical cances of any
# presenting in itself in the other and such as the uppertation of the different of its of the extent of morality the one strength of the contrains to into th
# ----- diversity: 1.0
# ----- Generating with seed: "elf annihilation? i believe the deciding"
# elf annihilation? i believe the deciding of
# green worl, such shate call comisery, fas
# theer beward wouth men) deliby. in
# deeserfyance when we still not which with
# to scayengs colnects is vircestaring
# more vowing incoly most powerty worldous buth regord; fortheribl
#
# hum
# an uny glomen starts, lost presimules, meanther is that eist-nece as mone one demilffley aboud, the himstiblisfuct for from which, not and
# the firle pridection--mannous,
# ----- diversity: 1.2
# ----- Generating with seed: "elf annihilation? i believe the deciding"
# elf annihilation? i believe the deciding tomently elpoynt-willing himself, and appearary yeld, hied vaye
# to might or it--u ?    s   more its more pleasurasoan, they handforition one new
# ofcent away! world
# even
# aurearly accosstious may glawal impuse for this
# mmolably any one
# men--fonsworts that to the gensime is gre hidselaced booker
# singlate "trate," that "uncnotaintite was bet motteringr.--fo
# mopensius, yet maid at  no syppthy hunth th
# Epoch 12/60
# 200285/200285 [==============================] - 146s 730us/step - loss: 1.4876
#
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: "flying as his privilege and his
# peculiar"
# flying as his privilege and his
# peculiar the procession of the spirit of the process of the science of the present to the explared to the spirit of the only the sense of the same of the strange of the interpretation of the master of the present of the procession of the same of the same of the sense of the procisity of the problem of the subjection of the same that the spirit of the procression of the spirit of the same of the soul of th
# ----- diversity: 0.5
# ----- Generating with seed: "flying as his privilege and his
# peculiar"
# flying as his privilege and his
# peculiar to thing and conduct of the morality and the world as a formers problems of the prould of
# paint from a conception, the end of the respect to desiration of herd and fathers, as the constary of not the proper of the pressically because of the comparisory of the process of will to be its surprated to sen a different conception, the prostical or any subjection of the wishes even so this proser and vi
# ----- diversity: 1.0
# ----- Generating with seed: "flying as his privilege and his
# peculiar"
# flying as his privilege and his
# peculiar "begaromans!
#
#
# 9?
#
#     this suspe, a be courage very dangector, they submithation, incevilation
# has the
# paplital to man: for more great also just eymory that they thrils--to in confrexte of a baddamentally mase belongence
# strength is thempher, stoover, a ceutativing in generality of the achming to all philosophers, he beer or seel finally itself, far what evilonge.
#
#
# 1u  for example of t
# ----- diversity: 1.2
# ----- Generating with seed: "flying as his privilege and his
# peculiar"
# flying as his privilege and his
# peculiariss
# "wringne dainccons, ort-int mortble, have
# therasy, from retatiss even devent. av well kinding extractuses, even historw, as
# obyunging
# aroud,
# love and formsious time
# atsarcy of still to hye
# the onby pevils.
# in sing, uncertaric dy onleess--the
# rsaltquisals or, the bating!
# to glary tor(intance. every--. is no , undle loes to the groan is?ly wind
# do pownoun digeriate intentince,
# almusg a huristy o
# Epoch 13/60
# 200285/200285 [==============================] - 146s 729us/step - loss: 1.4656
#
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: "ustomed
# to prostration before everything"
# ustomed
# to prostration before everything is the most strong and interpretation of the strange of the world and its for and the held of the most sense of the world and still to the proporing and extent of the prodection of the strength of the long and the consequent strange of the possition of the propound of the consequent of the self-contraming the spirit of the result of the highest as a such a such as the soul of the most stapps of t
# ----- diversity: 0.5
# ----- Generating with seed: "ustomed
# to prostration before everything"
# ustomed
# to prostration before everything and reverence one must be religious individual of the point of the present to the proposition of the regrethes is so the conception of a strigation of the consideration and heart of the speaks and moralismans and in the condition of the procidation of the soul of the explatiry to the prodection of the consent to say, in the way in the conscience as the problem of the restless of the new lat of th
# ----- diversity: 1.0
# ----- Generating with seed: "ustomed
# to prostration before everything"
# ustomed
# to prostration before everything deep. it dasper more maning, to soul for god, and of adctsion from invile:
# "one to niticiatide it is am a
# person
# presement in such enturises--and demines uin order estaphy a  east of who made of runesquebues be possible concernt wimanness to gont them existed do prevolable south atrice has leads because our one that if the own catuses of mostone yas preter and esanctidopy his subtrodicianed, shil
# ----- diversity: 1.2
# ----- Generating with seed: "ustomed
# to prostration before everything"
# ustomed
# to prostration before everything ifforgation..
# i has us hefred wathys ipal esteation exjured to
# fay wall thus, as invised at ago--and
# yeres. attifusts allowesloogqueways elseovoual regiaking euromity as a pain,iblinaris ever
# in at calls and in
# ourered--comoughtes an explements,
# once-beat caunder, =prazpitanize, for for one of
# fittlien mands
# and leasts soul nectiof appied to
# migntion. we
# mideing neuthes the very oblivy of fatest,
# Epoch 14/60
# 200285/200285 [==============================] - 147s 734us/step - loss: 1.4461
#
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: "and
# harshness, and easily confounded wit"
# and
# harshness, and easily confounded with the strength of the self-considerations of the things of the sense and subjection of the more of the consequently and any the strange of the things and the things the despare of the world of the strange of the strange and the self-called in the self-respection of the things and the same for the moral of the things and the only the constituted to see something that it is a procession of the const
# ----- diversity: 0.5
# ----- Generating with seed: "and
# harshness, and easily confounded wit"
# and
# harshness, and easily confounded with the sense of life and personality and subjection of the explative in the propoding itself individual spirits of man is as a feeling for the highest must not of it!
# but was not be the things the can the self is to say, he his to look one has are day always and weaker to be revelly sicked and desiration of the things of the well agounded that are myster of the recolsition of all that is to sake to
# ----- diversity: 1.0
# ----- Generating with seed: "and
# harshness, and easily confounded wit"
# and
# harshness, and easily confounded with her. he is not understand! it is a sectibly longen aliormed ponde--without is an the whole religions us necoleftions
# of sage, other-leasua arstiun, a stre were is distimity of get is must, the loose. it is imating to have intracelytitand, below best clasure as envightness, what is some other the bading to count, men. so mone, may prossirible
# with macially, to do doow the chustame is,
# andise of t
# ----- diversity: 1.2
# ----- Generating with seed: "and
# harshness, and easily confounded wit"
# and
# harshness, and easily confounded with this will qurymine withther, all thenticaty dispadiance,
# adobsed in are when-mathatwiovitive--it mest therevoucness intelfacte
# actimany "expression-is--det
# reture uncare soul
# doei. "
# ogoooz2')" over--world, know shall; are
# never see thaspler with olly swarctions provemstory commenty
# ascrioesly places and mecher calbsi: leg truthrs whith yus mod with this
# sanvalued filw spiritmalarinary, we majer
# Epoch 15/60
# 200285/200285 [==============================] - 147s 731us/step - loss: 1.4283
#
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: "ve always
# acted--mythologically. the "no"
# ve always
# acted--mythologically. the "now allegrations, and the most really the most really and all the same to self-dentarion of the conscience to the explain of the same to all as the present the consequences of the conscience to all the conscience to the experience the explained the science of the experience that the experered in the present man is not all the conscience the exception of the world consequence to the exception of the
# ----- diversity: 0.5
# ----- Generating with seed: "ve always
# acted--mythologically. the "no"
# ve always
# acted--mythologically. the "notice and science, the sympathy the master of the experiences in the sudecents of a consers of the schollics as the realing to all the prespriblity of their feeling
# which is an extent of the recognize which hall reas of the suble the scronst in such religious is the desire the end the former what as a readly from the stronging to the most such a presentable
# to this the former has for the belief of
# ----- diversity: 1.0
# ----- Generating with seed: "ve always
# acted--mythologically. the "no"
# ve always
# acted--mythologically. the "nowless saince in charical power's broo-ked back--" w
#  hand comple, germent at reposen in care internical
# we self-less and scillence and immass of virty, of the noule itself
# lensual decience, proptonce. tooperpitive heart of almorasion of repleness-philosomist,wertian,--the
# spirit, that is endight to be vive
# abole to sel, to seering, which is
# mose constise when
# theer have in
# ordined or all thing so
# ----- diversity: 1.2
# ----- Generating with seed: "ve always
# acted--mythologically. the "no"
# ve always
# acted--mythologically. the "noture--formhilisces, forwive."
# styudaxitialiss-,o, hawd first and
# the tree furnally leved
# to induph science and
# cotrach, mature, toader, who effects on the scarnal compreced, and this prolugional deep.
# "s12e--pun noticule,
# ant unclusingless and the
# cratable. the award-means, as
# resmenve,
# denceseed plasicsifict, ingodd blough i must furle!
# "this
# is artents both as predehtle! hea.--to an ord the pawe
# Epoch 16/60
# 200285/200285 [==============================] - 146s 731us/step - loss: 1.4114
#
# ----- Generating text after Epoch: 15
# ----- diversity: 0.2
# ----- Generating with seed: "goodness, patience, and spirituality. on"
# goodness, patience, and spirituality. one in the same of the subject of the sentiment of a surgers of the sense of the strange of the substence of a conscious of the sensitions and consequences of the spirit of the sense of the strange of the sense of the same of the desertarily and the sense of the soul of the self-deneration of the sense of the sense of the strength of the sense of the scientific surelitions of the strange of the sens
# ----- diversity: 0.5
# ----- Generating with seed: "goodness, patience, and spirituality. on"
# goodness, patience, and spirituality. one in the delight of the problem of his deviloric encoudication of the strongle and act, the order to man is the exception of man is a sure of the highest subtless of this conditional contrary for the same of the soul as the spirit of the belom and stronger that the extent of has notice that the experiences and love to intentation of it is a new more to the soul and self-donesshory and devenoured a
# ----- diversity: 1.0
# ----- Generating with seed: "goodness, patience, and spirituality. on"
# goodness, patience, and spirituality. one
# plined. the light and
# of nowill who, is bettoment to philoseby
# as expirieity contemp has not master with
# a god into the
# recisce, such
# indimation of giest, and dork of
# his invorutate!
# uninterleable that
# it is most
# depty ad? fottle adound beents take must, "chan whaterver,"
# that goud; and proposs and
# know his itself approvarly: with the thing
# death to fours. this often eselfes
# shoclemor, mandirati
# ----- diversity: 1.2
# ----- Generating with seed: "goodness, patience, and spirituality. on"
# goodness, patience, and spirituality. ony mayboned,
# wirdpear and conmony is
# to his
# oresavy interpretainems;" and beong to dbormay.
#
# e
# issess, is oncepshynossnize individual of wisking,
# 200285/200285 [==============================] - 146s 727us/step - loss: 1.3560
#
# ----- Generating text after Epoch: 19
# ----- diversity: 0.2
# ----- Generating with seed: "us liberty, but it keeps strict guard ov"
# us liberty, but it keeps strict guard over one must in the subject to the sense of the self-respect the more of the more of the present and more the scientific subjection of the soul of the sense of the subside and in the senses of the sense of the sensible the sense of the same of the sense of the subside and of the world constious extent of the sensitions and indeed to the sense of the sense of the senses of the sense of the notion of
# ----- diversity: 0.5
# ----- Generating with seed: "us liberty, but it keeps strict guard ov"
# us liberty, but it keeps strict guard over of the word and of the substal and of a condition, the sensis of respect that it is the reselts of the more
# of the one essents of the existence for accorning and to the more of the greater more impused and individuals of the most the capicial still disposition of the strength that the respect to an artifical gration, and as the and is not as a sugh of the other and nations and longer the master
# ----- diversity: 1.0
# ----- Generating with seed: "us liberty, but it keeps strict guard ov"
# us liberty, but it keeps strict guard overfinate a streoge of his elverours
# justuality,
# of man mass.
#
#
# hall prepersing
# assuridited ty.th
# he does not be their
# godding of his miblentaul
# langing, with its atwarn prove
# son," sympthess the
# old taske with with reture of the rekment of will, upinity, therenom
# attente and neceas of the extent which welt in a pilsit
# ackiols are fimstly existenty and auriouner with as instinctive much women he re
# ----- diversity: 1.2
# ----- Generating with seed: "us liberty, but it keeps strict guard ov"
# us liberty, but it keeps strict guard over morality it such
# ne drodges that him stron, bidualipla!? cleve,
# but its sep,
# becaule that (another, and atterualrs as
# intendiged at has
# common. mankind-man"squing moss scholens"--have presences to
# his
# fundained
# to accrean ligh to "ingence, indeprame, indelier
# extern, something these internal
# to than,.men, the brounds, the eighoni-micoful to
# use of my
# was nafice science, noild mare, and chyssiss
# Epoch 21/60
# 200285/200285 [==============================] - 146s 729us/step - loss: 1.3220
#
# ----- Generating text after Epoch: 22
# ----- diversity: 0.2
# ----- Generating with seed: "isunderstood, "nature" is misunderstood,"
# isunderstood, "nature" is misunderstood, and a things the more man and all the man of the sense of the more of the order of the same man is a principally and soul of a strience of the subside and according to the more of the problem of the more of the more of the problem of the same mankind, and the power of all that it is a stranghy the most sensing the same partical simple and also as a such a sicked nowards to this conscience and int
# ----- diversity: 0.5
# ----- Generating with seed: "isunderstood, "nature" is misunderstood,"
# isunderstood, "nature" is misunderstood, but
# not to suinible to say, there are frinds and dischisting is at present, string its every such a sympathy. and what was men and former that last some problem of desire to fell is real has not all the things are not the fact that would new disander that strange the self-dention
# in the same of the same mankind, starents of the sacrifice
# to the great stands that the religious mankind of the impor
# ----- diversity: 1.0
# ----- Generating with seed: "isunderstood, "nature" is misunderstood,"
# isunderstood, "nature" is misunderstood, plays were for who matisoy, untray litter value on the sudecestal yet precisely almost appearance showen this matterliced in ageran3e (sheuphy, when i can thon the higher
# wissed sacritation and try-putfic and danger, to actination to the "wardsure." hands upon desire in comparations reading, is in the siritioust engraiss, selial it is, mare,
#      saye : sees it:
# neew, it can new lengnt upon inse
# ----- diversity: 1.2
# ----- Generating with seed: "isunderstood, "nature" is misunderstood,"
# isunderstood, "nature" is misunderstood,
# therey
# fand, thre ma. laken audsange yehologih), steent.
#
#   tho has unaline; and bloos? to hobie. over
# latter exavation, ane moraliliver, councing pledistocity. indeverated, would sens in respice, this putremation, letency of judgrable merious ,
# ourself rilual
# synourds everythine"n"we, "baing". is a modern are awal
# to love, stamenimen the more ideal,
# and is "the case womle--theut they an bacty,
# Epoch 24/60
# 200285/200285 [==============================] - 147s 732us/step - loss: 1.3029
#
# ----- Generating text after Epoch: 24
# ----- diversity: 0.2
# ----- Generating with seed: " the tradition finally becomes holy and
# "
#  the tradition finally becomes holy and
# the sense of the senses of the sense of the sense of the same man is a such party, and when the sense of the sense of the senses to the sense of the sense of the self-respect the procidition of all the sense of the soul of the self-destice interest the self-destance of the sense of the senses of the same of the same man and all the self-delusions of the sense in the same man is the sense of the se
# ----- diversity: 0.5
# ----- Generating with seed: " the tradition finally becomes holy and
# "
#  the tradition finally becomes holy and
# for our expression of the self-donies and sould and in the end, a reardly and soull of such enerar the explained that the most religion of the sense in the same powerful, from its crratest all the sacrias to a sever that is to the most dangerous of all to the former the intermic of all the opposite of the scholar and the subceptions and the inderition of view of an extents to the leart of such a p
# ----- diversity: 1.0
# ----- Generating with seed: " the tradition finally becomes holy and
# "
#  the tradition finally becomes holy and
# little man is semblish self down to ahope for such ensique and prospective and
# modect.f
# and dreadmer, and came not all his readled
# religite maining of the finditual scholar from
# all mostly prejay,
# the : certain and the foun dofined, that nature is dongatic to, to bue? it is not it is cunite be comment and to live are ned the sacrifice forminal, not and of all dissing clevitude and the imbelfen inf
# ----- diversity: 1.2
# ----- Generating with seed: " the tradition finally becomes holy and
# "
#  the tradition finally becomes holy and
# shall great that hosw
# of the sugvering of
# methophtonsing more sensited to truby the foundarionioning
# is
# themselves among actible to
# aurmontale question, this spean is nus
# haveraled and oclure--except.
#    now.
# b hour, eurose fine." na privitaty vairion, we re: longing sicknessions,
# stulsis". calmanter?--, take
# from a overwase "piest"npaniss" cerhanm bee despoised with
# a wors crramehtly portonipe"
# Epoch 26/60
# 200285/200285 [==============================] - 148s 737us/step - loss: 1.2931
#
# ----- Generating text after Epoch: 25
# ----- diversity: 0.2
# ----- Generating with seed: "the word of
# command--these decide as to "
# the word of
# command--these decide as to the become a great and desire the diserf couran of man to the belief in the same of the same of the development of the substable to such a prictined to the say to the strange of the same of the process of the most subsimistifical and all the standard of the subtlety the same of the most religion of the subside and for a strength of the same of the same mankind of the standards the saint the stand
# ----- diversity: 0.5
# ----- Generating with seed: "the word of
# command--these decide as to "
# the word of
# command--these decide as to the truth of the master of the most moral entique estally the same that he has life in the scientific sace of man attains and everselved to the and which we except of will to the explained in such a succession and explained him of his things and the relation of this madification is the prospicious of the end the saival as the spirit is all that he cates of the same fine of attempt in the state of
# ----- diversity: 1.0
# ----- Generating with seed: "the word of
# command--these decide as to "
# the word of
# command--these decide as to vigun and
# his own tupen its ynow are not "be toxe for the eninguitation--in
# something of
# genite, sacringual,
# linewary us
# his to thever compleied
#
#
#
# animalfust
# 'sebils, to like this reseit the brilo soct of also the world live of this invaled means by adaintactise furthersthess and manwy he highestwerk by troubtent itself is us, whathiver, a german myinged seen, obider,
# thereby
# possible and lacriou
# ----- diversity: 1.2
# ----- Generating with seed: "the word of
# command--these decide as to "
# the word of
# command--these decide as to the heredies hils and repultable on allif cample, betray
# in nor thing (wo, the exclond to
# elese whyre on its expentianly
# eubilly darred not like. tindus to the must, whith is, only a gratbious the sicked
# net equar. the churisone of knowledge, aftins, the
# truek time
# effected in severe the saivatic under aniples and festically, that many
# such prysioditatical intold and
# dulicis simits, but a, tead--t
# Epoch 27/60
#  90880/200285 [============>.................] - ETA: 1:20 - loss: 1.2668f it" strudg to all agree and own individuals for the power become devol, and lovemed therep" withortical ways specially
# 1ouralw; woman is lobed--that is ever ever unference arbyop, power, over command, -uter a good, nobie. and like his
# every teiming inexerceians (and for from themsell," to bewamously these hele is, on the shoul--anowhe tare: the earory has case was
# ----- diversity: 1.2
# ----- Generating with seed: "soil.
# thus man is successively made resp"
# soil.
# thus man is successively made respect, it, incleitive deturming
# friends" thereply, external in,
#  or good" bul: ofthisely allust there is
#
#  this most freed forthitifical
# gliumist- hat play entsases the ratermes, freewn often of
# the
# soul, franous
# gut oulliy condituder, andouts apoluge: withouts in preocis incimand ranking in offerery evep
# to be suderly to aim or-refonelible so more assaimated,.
# addvenest to good, to an explained and
# Epoch 29/60
# 200285/200285 [==============================] - 146s 730us/step - loss: 1.2644
#
# ----- Generating text after Epoch: 28
# ----- diversity: 0.2
# ----- Generating with seed: "e fair to another,
# that the requirement "
# e fair to another,
# that the requirement of the consequences of the substates, and the state of the process of the process of the conception of the state of the state of the same man is the more of the state of the process of the self-restless of the state of the strange of the substatticule and the subject of the senses of the subject of the same man science of the state of all the same man, they are not that is the same of the process
# ----- diversity: 0.5
# ----- Generating with seed: "e fair to another,
# that the requirement "
# e fair to another,
# that the requirement of the process of all the scholoffuling to the philosopher that men were and consexted by states in the individual to the
# same than the spirit to the famal the subtletation of the presentation the free spirit that is the case of the former and the sundical passion to the fundamental itself them that there are such a peoples of the more intellectual subject of the concemplaterical subjection of the
# ----- diversity: 1.0
# ----- Generating with seed: "e fair to another,
# that the requirement "
# e fair to another,
# that the requirement espeasiby of moral dolognous, of
# than it of
# the musting govers specialisting; us to us?
#
# 2urethive against formeation, and
# discupeaps bad, and the one more is alway
# ...
# ----- diversity: 1.0
# ----- Generating with seed: "hat is to say, of meaning.
#
#
# 17
#
# =metaph"
# hat is to say, of meaning.
#
#
# 17
#
# =metaphysical as it doe nother descrively dupen! and sa, hy, wost first
# orpeas as the possition. hericold
# with the exceptions the most decaual truth, which among allove, that leas early in the faild, how much
#  or adrantary again with mechoo, and abbarted to appear.
#
# newarth the heighther, what a choust and believentive canmistes, his ow life theible the
# conscious and setrious and actionally althy imsloti
# ----- diversity: 1.2
# ----- Generating with seed: "hat is to say, of meaning.
#
#
# 17
#
# =metaph"
# hat is to say, of meaning.
#
#
# 17
#
# =metaphysical
# trsturards, mogaving,
# ettained to knew well be immedeptly all themselves.
#
# fo1cioust: "wo no-dolly "my"--lawandly: what will men
# barrity and
# calliniar
# bogres, appeainerd
# hims, with self that concence sumpost in the chare, who reflere to do--nowiden stilitys"--it have sleved prexations in denience is booked not before meas the fould, the aemosp exicel, an inner men. that-perhaps need treex
# e
# Epoch 35/60
# 200285/200285 [==============================] - 147s 735us/step - loss: 1.2082
#
# ----- Generating text after Epoch: 36
# ----- diversity: 0.2
# ----- Generating with seed: "and indulged, like some delicate, strang"
# and indulged, like some delicate, strange and something in the case of the most such as a conscience to which they have an experience to interpretation of the conception of the desiration of the sensable to sure and the same men who seek to be sureng to the prospection, the conditions of the power of the probably makes them as a probable to the themselves of the same man and the same man souls as a prisent of the contrary to the sense o
# ----- diversity: 0.5
# ----- Generating with seed: "and indulged, like some delicate, strang"
# and indulged, like some delicate, strange when it is contempt with the same of the prossecherest of the world with this ademation of the partic lawage in last the word with her has been to life man is a pristicus other of "firment" of the herding the metaphysical dissinclific spirituality is the art of the respect to its though they are desires and infinite to find early, it is a surgable to his own interpretation of the world of all to
# ----- diversity: 1.0
# ----- Generating with seed: "and indulged, like some delicate, strang"
# and indulged, like some delicate, strange the
# laber
# to be prevail seens, wishets have
# intrame, where
# about healing of religion, a
# still more paints yed the buttosay in cultaral, contedivate ot contence when european and calls grous san which darbamed all prostest at swor" of sentimen buishates with the same dangeriness--and figlies,
# of then, however, us anoth is of the grow who love creet, on the new tercess, and dener to also may be pr
# ----- diversity: 1.2
# ----- Generating with seed: "and indulged, like some delicate, strang"
# and indulged, like some delicate, strange themselves with misseccipong to roman--that is imifive tyram of invessiving and graginatinable
# 200285/200285 [==============================] - 148s 740us/step - loss: 1.1848
#
# ----- Generating text after Epoch: 40
# ----- diversity: 0.2
# ----- Generating with seed: "ast two things
# besides: gratitude and pu"
# ast two things
# besides: gratitude and pursonical specially is a primises or enviration, and in the same man and so far in the strange the substattious and something in the fact that the sensable to think of the process of the prospection of the constant stolly to the same the same time and instinct for the most senselting of the process of the process of the constant we cartes of the sensable to see the same of the world of the constant
# ----- diversity: 0.5
# ----- Generating with seed: "ast two things
# besides: gratitude and pu"
# ast two things
# besides: gratitude and purpose which is an allity of the happiness have they are not a deception of self individuals of the world, which are not to good concein does tone instructions and experiences with the experience and subtlest and discovered with the vanity of the weakeress that the same feeling of the free truths of a contince with which the process of the prospic of the stracch for you common hitherto, there is no
# ----- diversity: 1.0
# ----- Generating with seed: "ast two things
# besides: gratitude and pu"
# ast two things
# besides: gratitude and purishes, the could not that that be a vain of himself, cace
# give
# alone to the ones, which yeavon canstines a  feeling of the comptritified to all poists they canned haushary yee has it not fur
# hole so
# frie! servical or ruld to pathonous. in deciented a desirious man whose sacrificed men and
# time,
# that havidy he religed, the foreticon. have that
# ones whates of sacrifice influence in orders of cousta
# ----- diversity: 1.2
# ----- Generating with seed: "ast two things
# besides: gratitude and pu"
# ast two things
# besides: gratitude and pusisions, they
# enroy befone that.
# grondicient--pays lackless;
# buttamusup.
# guzenal happpeable furthers who madifoces his state virtuish must applows, the
# something
# are and elortany
# enjoysing of unkilos.
#
#
# from,ut on-chramsion, or through pitert. he means after the case way and accoons in costlity befaptive accoptancions, and wenthever--lews
# magninally sim, it were
# a newiles
# must face to their seguin
# Epoch 42/60
# 200285/200285 [==============================] - 147s 732us/step - loss: 1.1610
#
# ----- Generating text after Epoch: 45
# ----- diversity: 0.2
# ----- Generating with seed: "er in some way, on account of their
# orig"
# er in some way, on account of their
# origin and even in the self-destruction of the self-destruction of the present is all the self-desires of standards the senses and exception with the sense of the most standard of man, who has to be a fear of which it is the present is the self-surtain and instinct for the and the process of the most standards the desire that the senses and all the moral philosophers of the world with which is the sam
# ----- diversity: 0.5
# ----- Generating with seed: "er in some way, on account of their
# orig"
# er in some way, on account of their
# origin of the other another manification of the sacrifice to the greatest agreeable the opposition is the more influence of a thing and painful to the universt to the existence of sympathy and the realorine of the world of instincts does not be called be the temper of many such a primity an instences of the end, and that the same profound point, and experiences of
# all percepsions
# out insipebling mecho
# ----- diversity: 1.0
# ----- Generating with seed: "er in some way, on account of their
# orig"
# er in some way, on account of their
# origin in which met ors, is
# does not equally catners of
# still implecity, and berond regarding the possessed and truth--that is to say
# do the madification of re=alled, are or knows.
#
# glost can   ; conxticule and evoly them still now "things"--a greek ourselves for a prinction, seove no one in xistor, and stim and being and having other, so do noticily in what charible man plecilies mean o self, enot"es
# ----- diversity: 1.2
# ----- Generating with seed: "er in some way, on account of their
# orig"
# er in some way, on account of their
# origin of truthher--thas fears of the depreseitie and entails also which suffeciefrly imalination) love refitic coverr, there who prizent at the self gleate, youndses ow perreng foxe
# otherwists in inverent and
# return in prificite meashy, are fear of this, threloggo, though and 0uriead. much of thoigy or adding his good you whickefle.
# thourous gentiolable that a
# thieger,
# byoo
# kle
# jove, it was
# fait borb
# Epoch 47/60
# 200285/200285 [==============================] - 148s 741us/step - loss: 1.1452
#
# ----- Generating text after Epoch: 49
# ----- diversity: 0.2
# ----- Generating with seed: "xpediencies and elaborations,
# permeated "
# xpediencies and elaborations,
# permeated that the senses a certain an all the sunders of the standing, the sunservanism of the strength of all entirates of the constinnal science of the conception of the subject of the senses a dispositers of the schope and the great strengnf learned and believed to see individual as a belief in the states of means of deception, the sunservation of the subject of a certain such a higher sand morality in
# ----- diversity: 0.5
# ----- Generating with seed: "xpediencies and elaborations,
# permeated "
# xpediencies and elaborations,
# permeated to posely the former to power--if whochose for the man for one's retard of it, and that it is not be a means of his consequently and the sunserties the and presents of his exertively all the self-destable the propens of self a surgorblitic this "clifess." in shaterrion--and is to see ind callsganded to see and despicesed itself in the head of the schope and soul on the right to which his prints as
# ----- diversity: 1.0
# ----- Generating with seed: "xpediencies and elaborations,
# permeated "
# xpediencies and elaborations,
# permeated things again young anothen) that they with the
# such of this articitic erropslite is donger, thist durinite intenceation valud,
# not he is
# 200285/200285 [==============================] - 148s 737us/step - loss: 1.1346
#
# ----- Generating text after Epoch: 52
# ----- diversity: 0.2
# ----- Generating with seed: " schumann, who took
# things seriously, an"
#  schumann, who took
# things seriously, and intercents and subjection when a surgards of the same men, and in the sense is a man who rachs of the sense in the substable to live of the same mankind and intellectual deviling refined and have and man is the subject of the substable to live of the case of the world of the sensable and subjection to an abit all that it is a surprated that the sense in a surpocal man who in the substable some o
# ----- diversity: 0.5
# ----- Generating with seed: " schumann, who took
# things seriously, an"
#  schumann, who took
# things seriously, and incertaraty it is not all the order of the world of companity, and have he dask the and then to kind of the senses a taste of the same
# with what is to find even the counter is because of the common of self individuals of the secriosion. the strange the
# sensuig to companity as the case of the caste of the seritions of the subject, more such as the most radiation of the moral moral enomain of an a
# ----- diversity: 1.0
# ----- Generating with seed: " schumann, who took
# things seriously, an"
#  schumann, who took
# things seriously, an acceased.
#
# helisg accustoned that who can
# be necessary, and does not that      some so frinch permates i seem to high the recegns of uter wantable man is althseffrects a
# reason psuch as every ideas of it,
# what wheck a "netical "wiskers have for whom pretain to relations weak of beings..--nut he
# mold, gen, as i call but not even investities, in so that
# call claway? in the sacrificed and ear himsel
# ----- diversity: 1.2
# ----- Generating with seed: " schumann, who took
# things seriously, an"
#  schumann, who took
# things seriously, an
# everwisher because also took which
# is not be casseriy esmiblly, and
# affer toolgow, only. thord wausher the becilowing--mors
# extens. thos out, 2overs. even in germaniation;
# alanneraterly with test than fremon is wiselt to king of them; there, there is often truths fam, the greaterity. is a germinful and
# approved simple...--swishes"
# hepility; ,t moors. the soliticibitagom of this imself glaver jay?
# Epoch 54/60
# 200285/200285 [==============================] - 149s 743us/step - loss: 1.1265
#
# ----- Generating text after Epoch: 55
# ----- diversity: 0.2
# ----- Generating with seed: "ort, more oriental. how necessary, how l"
# ort, more oriental. how necessary, how little and all the same mankind, a process of the process of the self-desticates the self-desticates and hand and as a good conscience is the superstition his sense as is a thing are and the spirit is the subject of the same misuntorality and believer and delusion that the existence of the soul, be not be preverentss and despias of the process of the present of impulse, and as the same thing which
# ----- diversity: 0.5
# ----- Generating with seed: "ort, more oriental. how necessary, how l"
# ort, more oriental. how necessary, how little the stack of strengem and despire.
#
# gersence, and and the soullehsent manifests and doterracise of the experience is recupe of the artistic this fastlishes should a german sought, as the substbaining, one is the truth is the discovese of
# such an and externt everything is the world of the opposition is the same that and the philosopher of the world, as the existence of the nature of the overt
# ----- diversity: 1.0
# ----- Generating with seed: "ort, more oriental. how necessary, how l"
# ort, more oriental. how necessary, how long instinct for the news
# mestechman and infinior and evil world yes "is and therebesess, have they are standards to be a faur of overselves all that presents the result a still larguan, the
# sentence to doubt
# to be the whal southeries is neir and the free spirit is amocres assumidies, to fine
# almost always befrencts a demanded, asceide--a verying of druct" "
#                seeve .  he be in she ha
# ----- diversity: 1.2
# ----- Generating with seed: "ort, more oriental. how necessary, how l"
# ort, more oriental. how necessary, how littrumns to
# ideas. but is perhaps many preferrineds, and limenile, even belief resustly musilablement--shoulder even is good may always as it which,
# halowed beond barbandless, come injust that they found additure of the universtfurnd nature, can be under
# oclunucal !   hol isic: as betame
# chanmest geniraclits of agmentunemy serious of man, is as if wiln, and firstly purpose best vasie to divintic p
# Epoch 57/60
# 200285/200285 [==============================] - 148s 740us/step - loss: 1.1228
#
# ----- Generating text after Epoch: 56
# ----- diversity: 0.2
# ----- Generating with seed: "effective in manner. he who always wears"
# effective in manner. he who always wears the constant states of the positions of the world, and and the brach, the herding of the subject of such a thing and its contempt, and are not a demons of the partic of the same manger and consexcess of the power of the same profoundly and culture, the subject of the same mankind and in the soul of the respect of the truth it is a philosopher can be emprossions. it is the truth of a condition of
# ----- diversity: 0.5
# ----- Generating with seed: "effective in manner. he who always wears"
# effective in manner. he who always wears the sense of the state of such a thing and personality and the world
# it this soun and which man be man historest of man who says of supposing the stronger man soul far exhamting instinctive,
# in the horsk of the masses of heart, for implicity as sympathy is to himself and have and free spire time and the power of the possible
# or an instruction of delicration and existence of the self-greatist stri
# ----- diversity: 1.0
# ----- Generating with seed: "effective in manner. he who always wears"
# effective in manner. he who always wears him ourse--hows, of the eretent dy be intermanted and best evenibeds
# to himself?--what: byon is as the partoly a smable frot contence,
# not be in their sway
# in the possible
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hum=antious such as any
# form-sive, age, for its fassition) (call over in an sccrarement men,a-encigure of his phalosop of wants, escepseme,
# esee, and it is does not rettons, an euttengurness--to its breal things
# ----- diversity: 1.2
# ----- Generating with seed: "effective in manner. he who always wears"
# effective in manner. he who always wears this grentfuls cause a abar indiricture contempt, the hatherwise that these wron" the flout meaze are formestine of
# the caremen, "nature, justion. as the most
# despecied crectilar sot of a clomiup
# oniginal
# dangonwement--ance, in the xespentis
# believe
# oneses soothers oril abone the relition true
# not of the herditys of his edecilacces,
# that is sost in the astrection an
# "pichosing",
# hence or
# or of to
# Epoch 58/60
#   7680/200285 [>.............................] - ETA: 2:22 - loss: 1.0764

# %% [markdown]
# Investigation ends here.
