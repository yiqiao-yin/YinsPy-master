# %%
# !pip install git+https://github.com/yiqiao-yin/decision_tree.git
# Out:
# ...
#   Cloning https://github.com/yiqiao-yin/decision_tree.git to c:\users\eagle\appdata\local\temp\pip-req-build-aclr3kap
# ...
#   Created wheel for decision-tree: filename=decision_tree-1.0.0-py3-none-any.whl size=2885 sha256=542dd8767e2021b0a84f538a6ebd2b17564ae301ccac55effcf578b7960a84b8
#   Stored in directory: C:\Users\eagle\AppData\Local\Temp\pip-ephem-wheel-cache-td9gvjqw\wheels\a0\ff\1a\06fa844b4a97ce6513f2e507e400ecec872924be91b6e14cd5
# Successfully built decision-tree
# ...
#   Running command git clone -q https://github.com/yiqiao-yin/decision_tree.git 'C:\Users\eagle\AppData\Local\Temp\pip-req-build-aclr3kap'

# %%
from decision_tree.tree import prep_data
from decision_tree.tree import fit_decision_tree
from decision_tree.tree import visualize_tree

# %%
from sklearn.datasets import load_iris

# %%
import pandas as pd

# %%
X = pd.DataFrame(load_iris().data)

# %%
y = pd.DataFrame(load_iris().target)

# %%
modelDT = fit_decision_tree(X, y)
# Out:
# Depth:  5
# Number of leaves:  9

# %%
visualize_tree(modelDT, load_iris(), type=0)
