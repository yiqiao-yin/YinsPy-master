# %% [markdown]
# # YIN'S MONEY MANAGEMENT (YinsMM): Starter Code Initiation
#
# This notebook loads a script and runs through starting code to investigate company profile.

# %% [markdown]
# ### Load Library: YinsMM

# %%
# %run "../scripts/YinsMM.py"
# Out:
# -----------------------------------------------------
#
#         Yin's Money Managment Package
#         Copyright © YINS CAPITAL, 2009 – Present
#         For more information, please go to www.YinsCapital.com
#
# -----------------------------------------------------

# %% [markdown]
# ### Execute Code

# %%
# RUN
# Input (stock info, date frame, figure size, lower/upper bound, list of verbose)
# Output (function creates a dictionary of data):
temp = YinsMM.YinsInvestigator(
    start_date='2010-01-01', end_date='2020-01-18', 
    ticker='LMT', figsize=(8, 4), LB=-0.05, UB=0.09, pastNdays=10,
    plotGraph=True, verbose=True, printManual=False, printSummary=True, gotoSEC=True, showInteractive=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# C:\ProgramData\Anaconda3\lib\site-packages\_plotly_utils\basevalidators.py:751: RuntimeWarning:
#
# invalid value encountered in greater_equal
#
# C:\ProgramData\Anaconda3\lib\site-packages\_plotly_utils\basevalidators.py:751: RuntimeWarning:
#
# invalid value encountered in less_equal
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-a09b2b7cdaff> in <module>
#       5     start_date='2010-01-01', end_date='2020-01-18',
#       6     ticker='LMT', figsize=(8, 4), LB=-0.05, UB=0.09, pastNdays=10,
# ----> 7     plotGraph=True, verbose=True, printManual=False, printSummary=True, gotoSEC=True, showInteractive=True)
#
# ...

# %%
temp['updated data'].columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Normalize Return', 'SMA12', 'SMA20', 'SMA50', 'SMA100', 'SMA200',
#        'DIST12', 'DIST20', 'DIST50', 'DIST100', 'DIST200', 'aveDIST',
#        'Signal'],
#       dtype='object')

# %%
temp['InterPlot']['chart']
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Date]   (value)

# %%
temp['InterPlot']['signal']
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Date]   (value)

# %% [markdown]
# Investiation ends here.
