# %% [markdown]
# # DEEP LEARNING: USING NLP TO CREATE NIETZSHE'S WRITING
#
# Example script to generate text from Nietzsche's writings. At least 20 epochs are required before the generated text starts sounding coherent. It is recommended to run this script on GPU, as recurrent networks are quite computationally intensive. If you try this script on new data, make sure your corpus has at least ~100k characters. ~1M is better.
#
# Source of this python notebook is referred to from [keras team github](https://github.com/keras-team/keras/blob/master/examples/lstm_text_generation.py).

# %%
'''
#Example script to generate text from Nietzsche's writings.
At least 20 epochs are required before the generated text
starts sounding coherent.
It is recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.
If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.
'''
# Out:
# "\n#Example script to generate text from Nietzsche's writings.\nAt least 20 epochs are required before the generated text\nstarts sounding coherent.\nIt is recommended to run this script on GPU, as recurrent\nnetworks are quite computationally intensive.\nIf you try this script on new data, make sure your corpus\nhas at least ~100k characters. ~1M is better.\n"

# %%
from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io

# %%
path = get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower()
print('corpus length:', len(text))
# Out:
# corpus length: 600893

# %%
chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# total chars: 57

# %%
# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 200285

# %%
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization...

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='sigmoid'))

optimizer = RMSprop()
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# Build model...

# %%
# helper function to sample an index from a probability array
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
# function invoked at end of each epoch. Prints generated text.
def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
model.fit(x, y,
          batch_size=128,
          epochs=20,
          callbacks=[print_callback])
# Out:
# Epoch 1/20
# 200285/200285 [==============================] - 308s 2ms/step - loss: 2.6773
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "ently celebrated a veritable orgy of bad"
# ently celebrated a veritable orgy of bad an the the the the the the the the the the an the the the the the the the the the the the the the the the the the the the the the the the the the the sere the the the the the the the sere the the the the the the the the the the the and and in the an the the the the the the the the the the the the the the the the the the the the the the the the the an the core the the the the the the the the the t
# ----- diversity: 0.5
# ----- Generating with seed: "ently celebrated a veritable orgy of bad"
# ently celebrated a veritable orgy of bad and the ang be fore in wo an ther sthit and an the the snell of an the the the the an the the sace thint whan s and ing the the the the mund and ang ange tho the mes and the gart in the mins the this in  he mere thit the the sot an th of ar the the carelitreng an the sol to thit an the an the the in of thed the the the thand in the ghe re the go s an whe ued in the tha the on for as the the se to
# ----- diversity: 1.0
# ----- Generating with seed: "ently celebrated a veritable orgy of bad"
# ently celebrated a veritable orgy of bad iftatag ofe sthidis aneyy--tor jouvers. ter. of whe colwint and
# mis oy, whesy pitit and mdasg ior ind ind or
# of  acyres,p- hlre se thd aibes ther ags cons ar oumuses suad theth psand on iagt
# uroralitt
# ichy st es bf awud led irs fimuns. a.
# mere
# tir toilge tarlen!'g, caso ghe mot ul tulen"otl ,phas, ery, paine sose ind shivy baly is pomecn is "ubth on wloligre saaly, and-?esgim
# me athe the sen andi
# ----- diversity: 1.2
# ----- Generating with seed: "ently celebrated a veritable orgy of bad"
# ently celebrated a veritable orgy of bad ce am podocpano
# d wirsthes ris merrle
# -hengvy theh fo sevaedeceighe cirdeal,"lit
# es oi frtoed ail "ae wherte
# ast ranlly
# drute;
# ornd, ms or
# awiry whamitla,erp,s
# or fas ifusy, n2 withe . -resis ptayt rs glr oolgnstter fad:
# beed er an cupy
# cej! ore" eremutisyt cy y t euchewl meem co t sferoor teynt of lestrhite,ciof o,
# suskle2 sict te. wias nof teuas.
# pras ca, ang whos, inguca1:?y, sind le,"cinlit
# Epoch 2/20
# 200285/200285 [==============================] - 306s 2ms/step - loss: 2.2769
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "me; we fabricate the
# greater part of the"
# me; we fabricate the
# greater part of the hathe the the the singe the the the the the preasting the the here the sting in the the serting in the preating in the the hand in the the the the the the serition the with the gere the hathe the sore the the sere the sure the the the sore the sere the hith the the sente the the hith the sure the the the the mand in the the sond in the serting the fore the inders in the hing in the the ind in the
# ----- diversity: 0.5
# ----- Generating with seed: "me; we fabricate the
# greater part of the"
# me; we fabricate the
# greater part of the that lewing and and it on the the the preestyman the hen the cerome in thith inse and is in the inat and radity in the here in the senting and the sope sure penest the comed in the eriond the is the the hathes, at of herestof in the the tich the is of the is hersing and thith the hand ather the aring with herered the bees in the ther in prensting of thith and in thes thate the s and the theit, as
# ----- diversity: 1.0
# ----- Generating with seed: "me; we fabricate the
# greater part of the"
# me; we fabricate the
# greater part of thet rant orlle sieghvinit. the hem, for hemonas, fat buis of wglang fim himed suile, hissrilswsthey whis evimury sol the genel,
# the beas besis : ous ind treste premal,,
# noc sefintoble anwthes
# or
# pertonge hatte
# cac
# ofrithouk, in urcopilincende, endieneve , outicr,, theal beee for sundichins whoy dees ana iowin in hed all fo hing
# witu dfpreno hil sungended wie, thith nvatduln henen wit
#
# ermont, falitt
# ----- diversity: 1.2
# ----- Generating with seed: "me; we fabricate the
# greater part of the"
# me; we fabricate the
# greater part of the spliout seded ndignis, parez ebpemtyagas who outhiches usew exwer to. !revediby not tiens ofkeris?.rel bopily. nto
# dley.
# teente outenss ithed c
# nmsisice, on"weveme ta nacm thaigho, in tiek sew os persodinse., fiy lo tie
# hede cuss,lsed, kis one vedillmat it adcoce, chadver sen. may thtisolertir,
# wam ht trtxertiliwhyd ime,". ablong,
# -pist enperel. best."iv onde ve tweinfo wu hiffidigly
#
# m1her oo wu
# Epoch 3/20
# 200285/200285 [==============================] - 307s 2ms/step - loss: 2.1263
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "und dinge]. this can be thought out and "
# und dinge]. this can be thought out and and the the sere the man the serion the sertion and and in the the and the concer and the sersed the self the and and and and and the ment and the sintire and and and and the man the sertion and the sertion the man the sertion of the preation the sertion the corel the sertion the sere the the the and and in the ment of the seres and and the sertion and the self the seation the contire the sore the
# ----- diversity: 0.5
# ----- Generating with seed: "und dinge]. this can be thought out and "
# und dinge]. this can be thought out and mon of the sore a the beite and a dere to that a dirs a the mant cante, in the is lation of thing be wat and man and man celfer the chain consed and poremit of dereng of the state ables and the ther the mers of the corsers in a marint and corely and the comsine for in the mantion and, but corsed the duth the connes the mon in the reast of the hall the ment of the sore the beat real soman the selfo
# ----- diversity: 1.0
# ----- Generating with seed: "und dinge]. this can be thought out and "
# und dinge]. this can be thought out and cysels whabed uve that--athor munve the toolinct of
# wedraloo tho the lias remintu--the od its thin the tal nceich sonp, ant iof om of in of a the sthlee itict the wegos. celrot in the
# fiold of a moung on that a lly sull that prister to be maanitalo this (boul we loul, of wheich preles--bice is in of is ivcaly that fuul in and to to whet rakeys buct, be oparin) seliss to m nts real, sury--scous ive
# ----- diversity: 1.2
# ----- Generating with seed: "und dinge]. this can be thought out and "
# und dinge]. this can be thought out and cintar will. cournble?-: of owh crecumon erratscots bee
# nsous to geegrlis
# )or on
# shal ittitnot moant las,
# iwutous nog? wall-!hand menceve! fraunt
# "belwisekes judts.,
# buhte, but en
# if the itrhaplal ceredivilielsing parigiily no deligion vernat"covarles,: tawe gration of hupres, oh
# to whe rade for it medinised a thofarion
# dicsescicibel f
# austhe neod as poledristy
# sevilel at with hof withwce doveriey
# Epoch 4/20
# 200285/200285 [==============================] - 306s 2ms/step - loss: 2.0268
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: " any sense, it is
# a question, always, of"
#  any sense, it is
# a question, always, of the sened a soment of the sore the promed and itsere and and and and the to the mand of the sencestion of the senet of the consertion of the reare the hast and the sere the preand and and the seregs the ention the senter and the man the persention of the more of the hast of the lofe to the sore the is concestion of the sould to the persenter the sences and the has in the sentere of the sore the s
# ----- diversity: 0.5
# ----- Generating with seed: " any sense, it is
# a question, always, of"
#  any sense, it is
# a question, always, of the gore and hesse the are the more such is the ape indelf are parion of nether as for has the homent and and and has it is of the preatere the serest and ray conselsed and the sould and caldes the farte a with the sance and the ford and and and sound of the geatoun for the reaigion of the siching to the conterstion in the perupest cande be in the peroto. one comend and sperition erounte for the
# ----- diversity: 1.0
# ----- Generating with seed: " any sense, it is
# a question, always, of"
#  any sense, it is
# a question, always, of the woral, the meded far envewian the tould.
# ed
# os nelive is foy
# surnomemal thes it singlieg
# ald bereseifreandous of montlifutervery, eabcougelfusty
# ithive at may. will thour "enve fer now bes sals;
# fble muststaun)-, atind hichict andingainly the
# froutsalaid cor. musess, hawyelt hroke that. orancore wouch of
# anly of maly inly reans modied lod-gored thing solly.
# cakise a sores eaticisualsels--ohal
# ----- diversity: 1.2
# ----- Generating with seed: " any sense, it is
# a question, always, of"
#  any sense, it is
# a question, always, of ain ary aangevile man uren sodare-dumanal be wowuthey lamt norl
# everf oung
# fould ushith pebouy our
# estensy hounk lowe."
# ne in thingialy
# netoo the uspentaiss cance o
# deagnod fir.
# sulpeceffrligaluy corsiont,,
# comenqued
# we htheon it ka nhess rof steld."
# -o ppeanctergeer, gurh, urvactint orl sentu lice, be ain beeblam t ithey pochoupl!--han thue, a dit not of co,fllysequmiof is seciod,
# to elfesiike m
# Epoch 5/20
# 200285/200285 [==============================] - 302s 2ms/step - loss: 1.9517
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "d is not to be taken too strictly, but s"
# d is not to be taken too strictly, but so the such and the suction of the suching the sould and the such and the such and the sould and the presting to the more the prection of the sure and contict of the man in the more the section of the suncestion of the such and the his of the sulfertion of the suching the mast and the sisting the suncestion the ores of the more the man in the man the senfertion of the somention of the suncestion of
# ----- diversity: 0.5
# ----- Generating with seed: "d is not to be taken too strictly, but s"
# d is not to be taken too strictly, but self this hat in oun long, the sould, a wall that in a promont the indicinition of the mand the more and and indelf its of the searnes of the forting to the muration to and and suble the persting to the proon musting the fored
# and mont the sounger all the for all cinstian into where who more more the arperted in the suculitamal and and the preching to and and and by a man the mand in a soment of th
# ----- diversity: 1.0
# ----- Generating with seed: "d is not to be taken too strictly, but s"
# d is not to be taken too strictly, but still of disity whach andorter
# the sould pors of forenten of theus, as to the
# othings may sunctulituatabeed spprecipeeat not
# ma yith. cuntriusto, or werthtes wit
# oundfortuld not weng wis lome promspophimed.
#
# p9iloprenf that it elvopred wand
# willdef--comedlidis .f therefow
# the wal inselven, to bnangal pabliog tads, their hander to chistion lodet ofre them, on woral urmand his prapoy? renteffremter.
# ----- diversity: 1.2
# ----- Generating with seed: "d is not to be taken too strictly, but s"
# d is not to be taken too strictly, but stings of intoush in but
# a fifaticasef. me everelfod: onconglematly,
# be anupreicr, whoul
# is
# lapgrounst deaviretl, that
# himself
# the porpelugulad
# ssoutser
# ssigmanpence of ftith for smecrede is cacsthysels in, moan thomat
# thas stitcing theroon: as ars""scottine of thit hersin the ,
# quelest of memunatiry not that heabing is
# murallevea, is cungeevess,
# imita
# elf aga."--ap if that doar, " o leved wedlakit
# Epoch 6/20
# 200285/200285 [==============================] - 305s 2ms/step - loss: 1.8886
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "tful letter of galiani to madame
# d'epina"
# tful letter of galiani to madame
# d'epination, and and the still the contical the san in the will the sould and the pristion of the constinct of the resting and and the prosting of the prostire and the consent of the sperition of the all the prostion of the contint of the pristion of the pressint of the singer and propestion of the section of the such a sersting the propention of the instind of the prosting in the proscist of the pristin
# ----- diversity: 0.5
# ----- Generating with seed: "tful letter of galiani to madame
# d'epina"
# tful letter of galiani to madame
# d'epination there is in the really, is which exelve of the theis as a hanger and the fortement and it all the ancerate would every morally where and really in the more the are on in prosted and not the condedly in the instinces the concelf the forsthal the regated man it is an ame and requince to the will
# it the parter and perease with in the presist the evirtation of the rast as the ridention of every a
# ----- diversity: 1.0
# ----- Generating with seed: "tful letter of galiani to madame
# d'epina"
# tful letter of galiani to madame
# d'epination the desired, and cention and and alliun ined
# clantef obalusity, and its rewaling bad acthanss strougs men in meallis, how the ytile foreevation, to porso kerenghe it the this distons staid propothing forstar our theal the entally one tome in she distlere
# elsos, and ast indenw, werand purease,
# nawnated. it ertepion on the mamile, the
# orrige; priviol, in a or ally uther not hand on the proded a
# ----- diversity: 1.2
# ----- Generating with seed: "tful letter of galiani to madame
# d'epina"
# tful letter of galiani to madame
# d'epinaps, metr day "ufo"": whougtty han thay mose phosict, it eviint ,o
# the
# coust as pir. hidghag
# sturbnact acto these necres, treaest
# for him nos suckinstany, and nowaclefguritienttor--no renierts--an weceus us: yexpedely; ald neaun fa: to that
# or entortiods of himhlins the "ouliod".
#  now
# raduged in what ghon
# . blway ha verist, bevatusing deisration, of thit
#
#
#
# u.h
# detie of
# s recenfile wee dotanc1i ; 0
# Epoch 7/20
# 200285/200285 [==============================] - 306s 2ms/step - loss: 1.8499
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "s know, and consider it
# obligatory to kn"
# s know, and consider it
# obligatory to know the stind and the such a more the present of the still the prosting the some in the regard and the precentions and and the suntention of the sented and the still and in the still the moral the propling to the man in the man is the prost and the still the forment of the such a religion of the pressict of the wand to the man and still the more the resting the some the section of the mast and man
# ----- diversity: 0.5
# ----- Generating with seed: "s know, and consider it
# obligatory to kn"
# s know, and consider it
# obligatory to know sech as in the inself to presting in the can lenes for the sume of the gent as the restince of the man of the repences of they and all the way not it the cimplent to the stultes and whole stand to the will ention, of its the indict to and not form of
# the sime to thebrenge the constimation of the senfly in the sare the belige of the super; the persan of restarness, the more man is is the constin
# ----- diversity: 1.0
# ----- Generating with seed: "s know, and consider it
# obligatory to kn"
# s know, and consider it
# obligatory to knowing of plestirt husoness mandly itsolite, alwative it lithonimestacaleds betous tho vithulese to man ars
# hainize to susor--desidve ond whamery to hight perent stmen of
# elanger-ant a wese be is a verulothund their eviticationt.-
# it isting doucess we one as whoral hevere, or to nething himmotect, of the inglivution of
# exilstor to and and to maninod fool that stay hongrers, and fited as the moreppi
# ----- diversity: 1.2
# ----- Generating with seed: "s know, and consider it
# obligatory to kn"
# s know, and consider it
# obligatory to knothum grakes of then so benolang, thems anough, elary quednat of
# ecisulizarist".=-, ard some firdich ie whach
# one denwisc aliuld in the
# welly sumrya-herpato "bit noved sccosd is opry preceators ofrentiond i
# fnoliels, is upwere long live the stemuve wito man itwoent, the yil and it be
# y.gere cousod alded trow to world." agl3, arouglo, ha can
# muth way neliwithe. thism theiss morinuued
# deficer lide
# Epoch 8/20
# 200285/200285 [==============================] - 303s 2ms/step - loss: 1.8012
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: " anything, or blamed
# for anything, and o"
#  anything, or blamed
# for anything, and of the still to the such a some the soul the such a such all the sould to the the sould and the such a sunter and and the such a sungen the such a sunger and the present the such a sunter the consed to the sunting the soul to the strenges and the such as the such a surting to the soul the streng the regard the sould and the sould and in the sould as the such a sunger and the such as a such a sunter
# ----- diversity: 0.5
# ----- Generating with seed: " anything, or blamed
# for anything, and o"
#  anything, or blamed
# for anything, and of the proped he dower and been one condices the who ore desernations, the scoull the such all on enity or the great
# be man cententing of his not regard the roght with the soul freaked in the insore which are whilves in the to the good the restration, stird, and with the such a sentes and dong in the world it is not in the posseffor the most in the plast of self and his ston, a sust, the reperstion
# ----- diversity: 1.0
# ----- Generating with seed: " anything, or blamed
# for anything, and o"
#  anything, or blamed
# for anything, and obew robaring,
# howave which a want the liectean
# prose of this conelwhy as therever? ids in hild
# one onver inte pramowelt--the hildwann that coner-to his lipes reamerty in ghenescemeration light girence of the condicines, it distory
# lange zany evared-eased, wher epaind of herd senfess and pursold all of wall
# tuak as moralf is. rele, and ?hyoginst protimes. han do it, alto, who can "robed traty on th
# ----- diversity: 1.2
# ----- Generating with seed: " anything, or blamed
# for anything, and o"
#  anything, or blamed
# for anything, and of souks of udermoring of mo pedevania
# "for
# a and accens ty dofad havery necvewsl iggoved cale a colt badived were by nfelltil.=-expors in and suphist tray beed soge lidgeac, we drakent? in what hore mary in intelthing thus is foll
# nemity deves, haveire hower thersathever and stire to ti now repers of which inwastahmanceg a
# cirond-ridned only, inverthe-efong, be
# oul obly soupain accames a dotrve, e
# Epoch 9/20
# 200285/200285 [==============================] - 302s 2ms/step - loss: 1.7498
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: " at one in their distrust of punitive ju"
#  at one in their distrust of punitive just and the sentive and and the proble to and the revery and the sense of the self--and the prose the propoding in the senting and the subelity in the sense with the master and the precers and the consequent the must the still to the secrition of the prose of the sense and all the sentical and the such a some and and and the sentive and the soull to the proses and the master and the proses and the
# ----- diversity: 0.5
# ----- Generating with seed: " at one in their distrust of punitive ju"
#  at one in their distrust of punitive just the restran and the constines and and the secration and sech the readent and the ord in every as an the pristing interpopentian and and its sund the world to the man of the human the read all man
# and the ered the free surition, panss of the must it its of and means and the repirion, the readralist and refiles and even and the puptions to in the long this lake the prose and prose and for the reg
# ----- diversity: 1.0
# ----- Generating with seed: " at one in their distrust of punitive ju"
#  at one in their distrust of punitive juct to the canm. it, lith in vint, eave were in
# witnle sustirs ansast distmanto, whatether and there
# every"dreit contrative is treas,
# with postt persent who care of the dispodity fir. they
# inwerthism, tere, and toull afmething of the
# corsent to himsely the poonc of sulfeminess to sect
# ans its, the thand and i seepined to fis for full
# propting
# for dredens, readen in a vidday as the trusem, as which
# ----- diversity: 1.2
# ----- Generating with seed: " at one in their distrust of punitive ju"
#  at one in their distrust of punitive justray re frust of eligain, yeh roll-sulfimals in divainbly, an acrour "norlive miatec and pildist, engly thas lomonay man caluatly heart opherion that
# we gadalys "esiculituen, apon, there a mort
# to low !ne vore gencuin"kivale" hese we expersiataphyansing "pressapps, to has notlivey thest" and hellentiproly, we endegopement!--exars.--mot is,
# and mide phonopul takere",-neer sudely,"
# and lov conrais,
# Epoch 10/20
# 200285/200285 [==============================] - 305s 2ms/step - loss: 1.7160
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "eived and born in sin, and in the intole"
# eived and born in sin, and in the intoled and the still the strong the strong to such a strenges and and the still the strenger and the strenged the such a self--and and the streated and all the san it is a frees and and and the such a surtion and all the experiention, and as a serstance of the self and and the prose and and more the spirition and of the proses and profored and and the strong to the strong and and the wast and and and a
# ----- diversity: 0.5
# ----- Generating with seed: "eived and born in sin, and in the intole"
# eived and born in sin, and in the intolest, contrance
# of the secse the aratests of the has self the one all the propoble and the must is a fation that he will to an and the most at even it is and and and the prowhy the will in a plarest to the
# exare, and the exception, and perhaps and the procrets of the religions and prostunt of the can of great and in his conscience, and all the strange, and experian in elance, and and one and the wil
# ----- diversity: 1.0
# ----- Generating with seed: "eived and born in sin, and in the intole"
# eived and born in sin, and in the intoled man suphope it as have alsome for
# and bewance, ot but natutt and pupposed raken stros? a
# phishobod it of them regures be that virttive,
# drom greator arouthes "wimely os entonovated to
# t neen matisuaude, es for enterfif
# class to is in precausing with mors be imasmantion, ruch chrass thamstaphicsiatey; ind other no
# mame of lon apon the recupres on als ityou takeom to
# stall; in gurately excempalish
# ----- diversity: 1.2
# ----- Generating with seed: "eived and born in sin, and in the intole"
# eived and born in sin, and in the intoled almont at wheret a
# itusanimules
# and their cesple of the parhs bedery and armunce)
# sagt andogresm that of a reropp of fcomssaliaim as in
# the then exfinedne. to blifically cuniedun a camage.
# adywatuich when ous not dond would but know prate and y mistnvendikinc--natuwats aptithte--a man
# are of them yess whee doer worn nacke tomet
# hustrcemalues, oncy"und of which "as
# a rible," as elstifuled may lon
# Epoch 11/20
# 200285/200285 [==============================] - 308s 2ms/step - loss: 1.6869
#
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: " my writings have been termed a school o"
#  my writings have been termed a school of the soul of the self to the section the self--the still the prose and the seeps of the consequent and in the prose and in the soul some and the prose and the prosien in the sense which a self the propority of the still the sense of the consequences and in the self the such a still the superion of the sersent of the still and in the still in the consequent and in the sense of the string in the st
# ----- diversity: 0.5
# ----- Generating with seed: " my writings have been termed a school o"
#  my writings have been termed a school of the presention the desentalical consequent and in the consequences and every and prosicis and concempors in the purious and in the dights or with not the eamention to which with the consequention, and proient in the state the stand the plow can out of
# yound of all these which ger the and conters. he have and more as the weren as actions, and something and are the
# seesianes, the apperies which he
# ----- diversity: 1.0
# ----- Generating with seed: " my writings have been termed a school o"
#  my writings have been termed a school of a sometrative histernest of
# yesesss; rifisiop of the giddably of their gearhes, remistiled thene dofatient, and schers of somen
# in n bee, and to is the stronges", it is in
# the moralsing a palse-cenfuicoud hos to being and then rewards
# ut as they its and mann fach callice of has in why him wat dividiontoud chome consedfuch willing soce, with
# as the resence "formina orser anits all the compled and
# ----- diversity: 1.2
# ----- Generating with seed: " my writings have been termed a school o"
#  my writings have been termed a school of icnol garely
# lares-led?" it is grishived been of shece. nelisy ersting a prrsensingiu, we soul exflyop, theser, wy
# lase"
# ourseetis of hus muce. new yef ever an than disual something is soyous depertatienlto. and
# riflece)." with sheless, the gonowiced
# withonges tould no taght-love,
# theresine., armances" calsural in the suprifalic quess, actowophes in inveries. theroum anselven to short aroings ce
# Epoch 12/20
# 200285/200285 [==============================] - 306s 2ms/step - loss: 1.6613
#
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: "d those like thee, and whoever else requ"
# d those like thee, and whoever else require and the master and in the say an and contranting and the
# concernanted to the concempod the such a surthered the stand to an action and in the consiction of the will to the man is the inderstand there and in the subjection of the such a seartion of the conscience of the stand with the such a power and and and the experience and their learn in the conternal and the can it is the consiction of th
# ----- diversity: 0.5
# ----- Generating with seed: "d those like thee, and whoever else requ"
# d those like thee, and whoever else requise of the persences thereone and and more the perion of the sporthought, and of
# reading as the has ey the expecience and in their one the amother the selfest attistowing and conciple and their of which
# the instand the hamper their master has lovering to the experiences to a strenger, must as the expecian and ran in there are
# this live in the can for the clarion and and has a
# castermence and and w
# ----- diversity: 1.0
# ----- Generating with seed: "d those like thee, and whoever else requ"
# d those like thee, and whoever else requition. it rlisost is the pleasure and
# without buthinds awnoteds and and bownrevity of stensive
# -at the head in which "had rrowling infuch in wan inficenests no has gurhthere.
#
#
#
# scholceover, and which of thus about ofly in what
# everything to inderitsions of evile and a
# that oneterntaastar and morantions as in thut wothing am to a willibat in
# of can foroting frestly as in itsew in opear as in.
# ther
# ----- diversity: 1.2
# ----- Generating with seed: "d those like thee, and whoever else requ"
# d those like thee, and whoever else requention of a crotuentainf, this,
# there his "sesparander wemnogate. and frombrestionesmeffreinds, ane
# edivil nothomity. "wholged pymiiusly a factatian: ancamen for
# a brope-cansoumon-cive fordaniess (perhapogniins or-lof,
# so musations: unpertanch--hobewiat were a knoend of an akefoll theyry with racerouthy as y "kand uban
# as lay "achingliog--as montouther: it if oun time
# contrantes came posstiesain
# y
# Epoch 13/20
# 200285/200285 [==============================] - 305s 2ms/step - loss: 1.6367
#
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: "s to our knees!
#
# age, alas! and science "
# s to our knees!
#
# age, alas! and science and the strecesses and inderstand to the something the prose of the reserves and the speak and in the self-theness of the something the theing and the consequent of the stronges and instinct of the seest and the strengention of the such a religion of the conscience to an a their the stronger and the something the problem and instinct and the soul and the strenger and as a problem and as the self t
# ----- diversity: 0.5
# ----- Generating with seed: "s to our knees!
#
# age, alas! and science "
# s to our knees!
#
# age, alas! and science and reader to has blear as a read as they they has and such a moral as the contrical to it is the there
# is the contrances and every himself, in a freated all the
# strenging with the world and about it with the spetrether to the
# probound to is a probount of the more to an invations and and in the case of the concempod in the great of the entianical smating
# and and reporting is has its, the such a mo
# ----- diversity: 1.0
# ----- Generating with seed: "s to our knees!
#
# age, alas! and science "
# s to our knees!
#
# age, alas! and science of haster only phemouly-caners of the
# soilugucest lioting, intained, who low he prebablibits, now
# more onfached
# lyst shollo.
#
# many net, when valiking awnewer, and eass; mact, srupt, has, the insturcref and
# caid hour giving wele, the listed to or on that an
# agot the, that contectionainnces in its can tratust unon
# wele as clearusely getring of causop by suchely by hard
# notingre is natous, himself. r
# ----- diversity: 1.2
# ----- Generating with seed: "s to our knees!
#
# age, alas! and science "
# s to our knees!
#
# age, alas! and science thea philosity, that
# inctrutine of lead-diliblys, and commaniagion tever train
# as no itsildseled, are morad is steph exapefituble aprourss! and a wowld.
# ind mast neicances, of that there eppiriduled ey
# but comeguthy,"," mass oor'h verut,.----perhaps "liggretans to prefemnest and reneisantsied."
# "asial (tomengr: call grastiser clouidy and suskits on
# is know theo, in lifed nacced roun?ge the
# excepti
# Epoch 14/20
# 200285/200285 [==============================] - 304s 2ms/step - loss: 1.6163
#
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: "enomena" and injected its own erroneous "
# enomena" and injected its own erroneous and the superion of the supplies and all the superion of the self--man be of the self-conception of the self the self-interpicion of the superion of the self--and the are the self-concemple in the sense of the soul a surtent and such a sulfured and interpire and the seef and self-render the moral the still the self-interpicion of the will and the problem and and the sense the self-will and the sup
# ----- diversity: 0.5
# ----- Generating with seed: "enomena" and injected its own erroneous "
# enomena" and injected its own erroneous of the great to the betion of the underition and reader the persing the enerong of an arther of the consict
# denerate the sense, a thing in the enting the his atter this previlitionous and as the strengting superions and heart, which man itself be about that which which i self interpeation of the world, the sore insided the sufficient in the
# consciences and have the probound that the uppostimation
# ----- diversity: 1.0
# ----- Generating with seed: "enomena" and injected its own erroneous "
# enomena" and injected its own erroneous remantive, readina intimaling,
# but can contrris by notencal naterer expethre. hought we
# neem, our ear lave with ranage.--the "welien muntlonted inkelfaris yimpenssion, from infuph and and accals tho god
# is the complace, unour mirele as they of long the same to liferempos or invicuadatify were it rager
# earoen, for its are men prostical man; all and
# uppereation. the blooker dividual only their will;
# ----- diversity: 1.2
# ----- Generating with seed: "enomena" and injected its own erroneous "
# enomena" and injected its own erroneous "forch while incourrelige, in artiprain of certaranity--hittwarnian, spere".--brecultiment, and perhopo ead,
# as to ereaghess)]ed hands of the blivenes, not
# whith resunts we exeeving intelluke ither ys--belokenis crounter,
# that is nos--has braning all schologivene! was" amansim
# this sthonged by notees. doal hand in iniursefilam somerungo
# of i himself, here , grown religidious and to will, of
# it bre
# Epoch 15/20
# 200285/200285 [==============================] - 303s 2ms/step - loss: 1.5969
#
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: "ation army"--if it be a question, howeve"
# ation army"--if it be a question, however the problem and in the soul of the theing that he would the order the conscience the conscience of the interpore of the probound the problems of all the probound to the world and the probound and the soul the master of the problem and superions, and the probound of the instinct of the soul and more the power of the concection of the interpicion, the problems of the conscience of the concerning t
# ----- diversity: 0.5
# ----- Generating with seed: "ation army"--if it be a question, howeve"
# ation army"--if it be a question, however and has experience of the wart it his new the power in the word with its can the depecially
# heart from himself, and has a called that an action, the whole the something
# in a still them an individual by not on the forment the
# hemint and confuct of life should perhaps to which with the conscession of after the sense the souln
# is an the philosophers the and exception of the more that it is the thei
# ----- diversity: 1.0
# ----- Generating with seed: "ation army"--if it be a question, howeve"
# ation army"--if it be a question, however which hene that
# out came to him ownehts of rementions, obledry, for its often that
# gelough that cincence these bane: the waing
# daniaritious,
# cannesist--anaching strong we fach, beluety--it itselity in the
# poor more wiscenst as a regurations we candnes and
# anoching, but otherity resporars anvaceny to feel shems to ange showed!
#
# ame to eleak opon, that themsists hordins, only the
# means, and excapt
# ----- diversity: 1.2
# ----- Generating with seed: "ation army"--if it be a question, howeve"
# ation army"--if it be a question, however "it them the werance us as rejected feriation
# thin whated, socard for hystice of enjorce.-
# the net intemptaed ut or immodstany to evain fal conditionapt on owegth peelsppays, withers.
# e which linnequatish, in them nackly grountehible of theiund wost even of
# prepued incenne" is prefapicciswars. "unkeroments chare, soetike ow we know ackings; a
# ory" prequided they ha bean saise uhandwinger complat
# Epoch 16/20
# 200285/200285 [==============================] - 304s 2ms/step - loss: 1.5793
#
# ----- Generating text after Epoch: 15
# ----- diversity: 0.2
# ----- Generating with seed: " "we
# truthful ones"--the nobility in anc"
#  "we
# truthful ones"--the nobility in anceating of the prose of the great and the stand to the stand to the most to the considerations of the prose
# to the prose of the prose of the consideration of the such as the stand to the prose to the former of the stronger and the prose of the fact, and interpire of the soul, and in the sympathy of the prose to the same to the stand to the considertion of the stronger and the stronger and prose of
# ----- diversity: 0.5
# ----- Generating with seed: " "we
# truthful ones"--the nobility in anc"
#  "we
# truthful ones"--the nobility in anciate to be partions so that the dogation, may according intolly to
# complicted to the disinged be the contrant some an the first to good
# and world as a man of the stranged therefore and instinct of heart the surest all to and the prosions of a will
# of the intrung to man man has really most
# sortuless of only in the conscience of the
# such a things not us an only into man there or which an one of the
#
# ----- diversity: 1.0
# ----- Generating with seed: " "we
# truthful ones"--the nobility in anc"
#  "we
# truthful ones"--the nobility in anciety as sake restict,
# a
# most form such gived bidran.=--eppearing
# such of and was not laty, whene the "dematicrable, the quaitly. their to
# some notions addeghal owe of caseful inwarody
# with own it" ord, to limable befly thingge morased grangerous man. to ing
# would a crospusion, the supate, non own taded
# in require are that wouth cunity--naringly peiloush
# "grow to do such yig of act in the histatule
# ----- diversity: 1.2
# ----- Generating with seed: " "we
# truthful ones"--the nobility in anc"
#  "we
# truthful ones"--the nobility in anconnizent understury:w or
# "ristopheded we dindjed--spreceptenchess
# weance in himself burd wordnest to woengeat ncouno-sound and
# yman becwainf, muchony wouldd. aboutious leas; intellabtion of man. tod
# canolize who le them."
# very remoaningly disphysinigrits ofter so, theres
# things: to thing in the jesse without propained has undeventalation drought" of hard our
# pocling them" to to thremsto, lurediged
# Epoch 17/20
# 200285/200285 [==============================] - 304s 2ms/step - loss: 1.5634
#
# ----- Generating text after Epoch: 16
# ----- diversity: 0.2
# ----- Generating with seed: "hilosopher on the subject of man is, in "
# hilosopher on the subject of man is, in the conscience of the consequences and all the respending and and the regard the strength and the self--the new of the considernal and all the the stand to the self--the self--the feeling and all the more of the still the regard to the prose of the self-cunture of the considernal and the most present to the religion of the prosents and and the personal and the self--the consciences and all the pro
# ----- diversity: 0.5
# ----- Generating with seed: "hilosopher on the subject of man is, in "
# hilosopher on the subject of man is, in the consequence of the most being the respent and the moded the deperations
# hours it have their deserved and the and and sure
# present propence, become in a the truth, as the are not been man of the such a pleaser the self-religion, also the more the personal proses, as the
# suppegse and destise of the will and dominess so germand and all the
# leadness of german man, but
# the power for philosophers at
# ----- diversity: 1.0
# ----- Generating with seed: "hilosopher on the subject of man is, in "
# hilosopher on the subject of man is, in consequently alw let have of reach diffleness," and a time to nelity himself goover trieve to
# imparabile the surelly clened light.
#
# speriuss entertationson-. what aligling torbirections. "god reade and is lefedestices--opinifes.
# "thuimst all entical "strangt, som
# /usr/local/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log
#   """
# ethive wittour notial ond in a compleasive and
# kind in their one memely. wher individout that he does adaysposioning welc quilice
# merely
# ----- diversity: 1.2
# ----- Generating with seed: "hilosopher on the subject of man is, in "
# hilosopher on the subject of man is, in their mose arain: slewal
# that i natured, it what as p hones, an by gader. an everything the oberry
# man atespluy ; lot womenks, to stuisct, deratenge); hishreciange what a
# heritahtatily, yoddy todry as rebigiows withing varites speriet would, slumbst. with, an ordering saibtlur, a
# peralenation. well-kels if silounused sureed as
# undarnow as in secron" bestores, to, the revilet--and
# thit can feed the
# Epoch 18/20
# 200285/200285 [==============================] - 302s 2ms/step - loss: 1.5501
#
# ----- Generating text after Epoch: 17
# ----- diversity: 0.2
# ----- Generating with seed: "f savagery or by a
# terrorizing process i"
# f savagery or by a
# terrorizing process in the sense of the stronger and the soul for the problem of the bad to be the self-man in the morality of the soul for instinction of the fact that the stronger and the sense and interpined the stand to the still in the stand to be a stronger and the stronger and and and interpined in the self--and that the soul in the subject of the stronger and the stronger and the stand to the whole and the str
# ----- diversity: 0.5
# ----- Generating with seed: "f savagery or by a
# terrorizing process i"
# f savagery or by a
# terrorizing process in a noting something in of the former to the point of the desire
# and exolurable reading the problem the great of the prose and prose who fulsticist
# calling been suspention of the was for instinct and the sensiation of the moral of the supposition of the soul such free spirit and of conterned and all that the sultestion and the sense of for command man for the philosophing of the former and beloffe
# ----- diversity: 1.0
# ----- Generating with seed: "f savagery or by a
# terrorizing process i"
# f savagery or by a
# terrorizing process is inn this onowible the noble exis namping tame it eys. but trith. in the gleary--it our least grine thria,
# a womon must be aboinds that rigation.=-its
# induntiting . who hone i feided and dimathers history? bow
# yevelfougn of i not of a conscience in him into cally
# to spetity of light, exustalts of the sincisuly with stages for incompossits to
# strivinsplewications. would no life!--many
# averwation o
# ----- diversity: 1.2
# ----- Generating with seed: "f savagery or by a
# terrorizing process i"
# f savagery or by a
# terrorizing process irselfoundesc
# fortencepty-its a bowed (the depense that mandingreforescibre
# and of bad cromes andypresse -ave wlature
# inly and belifical powergries, -selfemly plowerner
# liokion in sour carsunyly in these , hearn?--one thoes very equal
# for
# that pain to maguses apponsing for insclusual,
# the freedic justite evined, envarily diffiem. addingrones,
# antruirs evely naichted, cealimatifilous
# sough anpavely.
# Epoch 19/20
# 200285/200285 [==============================] - 303s 2ms/step - loss: 1.5375
#
# ----- Generating text after Epoch: 18
# ----- diversity: 0.2
# ----- Generating with seed: " of interpretation as artificial and exa"
#  of interpretation as artificial and example the profound the higher to the prose of the still the sense of the still the seems and the still the still the sense of the soul as the soul and the still the still the sense of the sees and such a something the seems and the stand of the prose of the still the properations and the proses and the strength is the stands to the still the soul and the stronger and the present the still in the st
# ----- diversity: 0.5
# ----- Generating with seed: " of interpretation as artificial and exa"
#  of interpretation as artificial and exall the same of the stand of the such a something and that and as to will to him the soul sension and the magice of the soul and the mose decession the truth and the true vanical and consequent to the more far of complets and person is also the great to do something to be without has all the most stand that he will for
# the suble difistive the such a this head
# man of the profound to be sense, that a
# ----- diversity: 1.0
# ----- Generating with seed: " of interpretation as artificial and exa"
#  of interpretation as artificial and exa
# modutuded and duted by the not flasp of ach in which
# behond pleasure." in easously us, he something often philosophoped gow
# one shay witt eneligateiny who coumal one withingeralse of the gor-atsentic no
# matisstitiments
# as hordy theeret prine and purhed dewer the peristic,
# dewertians of the way ore of the making the sould duthonions
# a mare, and this enspecience of andit struptic least commorstions
# ----- diversity: 1.2
# ----- Generating with seed: " of interpretation as artificial and exa"
#  of interpretation as artificial and exartifysdance
# by these
# somety hamping omeverver)--it uperway vain, gurstual made
#  penyend thet gocrests as not dose overit iks
# otseled neg of the problem, hastether, europestaged,
# cropetely and manionion) exidua.s feelismned, case, herethencom it
# geone proustical with redense as bodledwist (and ary more
# tapte, knoild asm an invocountaate neevers
# epiture. frone brole; is its itfering the
# mua has matu
# Epoch 20/20
# 200285/200285 [==============================] - 306s 2ms/step - loss: 1.5248
#
# ----- Generating text after Epoch: 19
# ----- diversity: 0.2
# ----- Generating with seed: "victory?
# over what? over whom? a riddle-"
# victory?
# over what? over whom? a riddle--the consideration of the happerity and the consideration of the stronger to the most dount of the self--and who conduct of the consideration of the sertional of the has all the most and the more the self--and and philosophers and the soul and such a religion of the conscience of the soul and the soul and consequent and the self-interting that it is the suressest of the sense of the stronger and t
# ----- diversity: 0.5
# ----- Generating with seed: "victory?
# over what? over whom? a riddle-"
# victory?
# over what? over whom? a riddle--speciently with the soul for examples, and the consussopher say though about and all all that he is the the the way be the instinct of the consicts of the moral the common the dimistorical and the powers of all
# the extlon of the highest the furthed and there as all the
# conception of man make the metaphymanic in the the make the believery and supersing of the experience in the conscience and himse
# ----- diversity: 1.0
# ----- Generating with seed: "victory?
# over what? over whom? a riddle-"
# victory?
# over what? over whom? a riddle--somecauss, a sulless
# as periltional mistood, an becape, weagher, folly to
# distance of were." the glass" for culpulneus with regard that very excep of the gratter. and their case his concess is to distactivalst of all the heads
# but as real doer, sote, and saffarse complece, the tend
# from whather of sudend" ragnisiling windsting, to itself hidseffieal, sholl
# adys to again acce, to beer strong musta
# ----- diversity: 1.2
# ----- Generating with seed: "victory?
# over what? over whom? a riddle-"
# victory?
# over what? over whom? a riddle-persomaling, not the
# ins-restracted, and not ut own rederme--in thain moon--which mo read
# spires agaitate, of womage: lictre. thought countual
# coustisip, latrs"; dverdience in his futturace, a
# icamay a s
# qumone conmition seling iderity--sempthamens as an owegre, can viloud
# asuliak
# but wart soungally and expressions opinion;
# is ilare injoyent endigate," for
# person
# wheneves
# "wild, rivad, abaknation

# %% [markdown]
# Investigation ends here.
