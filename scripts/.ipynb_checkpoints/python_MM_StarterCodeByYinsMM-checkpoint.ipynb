# %% [markdown]
# # YIN'S MONEY MANAGEMENT (YINSMM): Starter Code to Investigate Company Profile
#
# This notebook loads a script and runs through starting code to investigate company profile.

# %% [markdown]
# ### Load Script
#
# Let us start by loading the ".py" script from local environment. Notice that you should have "YinsMM.py" file stored in your local environment under a path you prefer.

# %%
# %run "../scripts/YinsMM.py"
# Out:
# -----------------------------------------------------
#
#         Yin's Money Managmeent Package
#         Copyright © YINS CAPITAL, 2009 – Present
#         For more information, please go to www.YinsCapital.com
#
# -----------------------------------------------------

# %% [markdown]
# ### Run Function
#
# Next, let us set up starting date and ending date for the data that you like and specify a stock ticker you want to look at.
#
# Note: one can specify "verbose=True" which will print out a brief summary:
# - stock price charts with adjusted closing price and moving averages
# - time-series plot of signals (positive means sell and negative means buy assuming using reversal strategy)
# - expected return
# - expected risk (measured by volatility)
# - tail of buy signal (developed by myself; and transformation of moving averages; for more, please go to my research site [here](https://yinscapital.com/research/) and click on "Buy Signal from Limit Theorem".)

# %%
# Input
ticker = 'AMZN'
start_date = '2015-01-01'
end_date   = '2020-01-18'

# Output (function creates a dictionary):
# Run function and save verything in a *temp* variable (which will become a dictonary)
temp = YinsMM.YinsTimer(start_date, end_date, ticker, 
                        figsize=(8,4), LB=-0.10, UB=0.15,
                        plotGraph=True, verbose=True, printManual=False)
# Out:
# [*********************100%***********************]  1 of 1 completed
# ----------------------------------------------------------------------------------------------------
# Entered Stock has the following information:
# Ticker: AMZN
# ---
# Expted Return: 0.0016
# Expted Risk (Volatility): 0.0184
# Reward-Risk Ratio (Daily Data): 0.0863
# ---
# Tail of the 'Buy/Sell Signal' dataframe:
#             Signal
# Date
# 2020-01-13     0.0
# 2020-01-14     0.0
# 2020-01-15     0.0
# 2020-01-16     0.0
# 2020-01-17     0.0
# Note: positive values indicate 'sell' and negative values indicate 'buy'.
# ---
# Basic Statistics for Buy Sell Signals: {'AVE_BUY': 0.0142, 'AVE_SELL': 0.0465}
# Note: Change LB and UB to ensure average buy sell signals fall beneath 2%.
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# Once the code finishes running, we can start to print the result by looking at basic statistics such as expected return and risk. This will be exactly the same numbers from printed results from above.

# %%
print(f'Ticker: {ticker}')
print(f"Expted Return: {round(temp['estimatedReturn'], 4)}")
print(f"Expted Risk (Volatility): {round(temp['estimatedRisk'], 4)}")
print(f"Reward-Risk Ratio (Daily Data): {round(temp['estimatedReturn'] / temp['estimatedRisk'], 4)}")
# Out:
# Ticker: BA
# Expted Return: 0.001
# Expted Risk (Volatility): 0.0159
# Reward-Risk Ratio (Daily Data): 0.0601

# %% [markdown]
# ### Further Exploration of Company's Profile
#
# If one wants to explore more, one can access 'ALL_DATA' which is a big dictionary stored rest available data downloaded from "yfinance" library.

# %%
# Give it a name:
ALL_DATA = temp['ALL_DATA']

# %%
print(f"Business Summary: {ALL_DATA['get stock info']['longBusinessSummary']}")
# Out:
# Business Summary: The Boeing Company, together with its subsidiaries, designs, develops, manufactures, sales, services, and supports commercial jetliners, military aircraft, satellites, missile defense, human space flight and launch systems, and services worldwide. The company operates in four segments: Commercial Airplanes; Defense, Space & Security; Global Services; and Boeing Capital. The Commercial Airplanes segment provides commercial jet aircraft for passenger and cargo requirements, as well as fleet support services, principally. The Defense, Space & Security segment engages in the research, development, production, and modification of manned and unmanned military aircraft and weapons systems; strategic defense and intelligence systems, which include strategic missile and defense systems, command, control, communications, computers, intelligence, surveillance and reconnaissance, cyber and information solutions, and intelligence systems; and satellite systems, such as government and commercial satellites, and space exploration. The Global Services segment offers products and services, including supply chain and logistics management, engineering, maintenance and modifications, upgrades and conversions, spare parts, pilot and maintenance training systems and services, technical and maintenance documents, and data analytics and digital services to commercial and defense customers. The Boeing Capital segment offers financing services and manages financing exposure for a portfolio of equipment under operating and finance leases, notes and other receivables, assets held for sale or re-lease, and investments. The Boeing Company was founded in 1916 and is based in Chicago, Illinois.

# %%
ALL_DATA['show balance sheet'][0] # annual report
# Out:
#                                     2018-12-31    2017-12-31    2016-12-31  \
# Accounts Payable                  1.291600e+10  1.220200e+10  1.119000e+10
# Capital Surplus                   6.768000e+09  6.804000e+09  4.762000e+09
# Cash                              7.637000e+09  8.813000e+09  8.801000e+09
# Common Stock                      5.061000e+09  5.061000e+09  5.061000e+09
# Deferred Long Term Asset Charges  2.840000e+08  3.210000e+08  3.320000e+08
# Good Will                         7.840000e+09  5.559000e+09  5.324000e+09
# Intangible Assets                 3.429000e+09  2.573000e+09  2.540000e+09
# Inventory                         6.256700e+10  6.138800e+10  4.319900e+10
# Long Term Debt                    8.670000e+09  8.159000e+09  6.804000e+09
# Long Term Investments             1.087000e+09  1.260000e+09  1.317000e+09
# Minority Interest                 7.100000e+07  5.700000e+07  6.000000e+07
# Net Receivables                   1.390400e+10  1.108800e+10  8.832000e+09
# Net Tangible Assets              -1.093000e+10 -6.476000e+09 -7.047000e+09
# Other Assets                      2.110000e+09  2.348000e+09  1.748000e+09
# Other Current Assets              2.335000e+09  2.417000e+09           NaN
# Other Current Liab                5.493600e+10  5.126000e+10  2.762300e+10
# Other Liab                        2.470200e+10  2.621900e+10  2.941800e+10
# Other Stockholder Equity         -1.508300e+10 -1.637300e+10 -1.362300e+10
# Property Plant Equipment          1.264500e+10  1.267200e+10  1.280700e+10
# Retained Earnings                 5.594100e+10  4.961800e+10  4.071400e+10
# Short Long Term Debt              2.690000e+09  4.350000e+08  2.840000e+08
# Short Term Investments            9.270000e+08  1.179000e+09  1.228000e+09
# Total Assets                      1.173590e+11  1.123620e+11  8.999700e+10
# Total Current Assets              8.783000e+10  8.519400e+10  6.248800e+10
# Total Current Liabilities         8.159000e+10  7.464800e+10  5.013400e+10
# Total Liab                        1.169490e+11  1.106490e+11  8.912000e+10
# Total Stockholder Equity          3.390000e+08  1.656000e+09  8.170000e+08
# Treasury Stock                   -6.743100e+10 -5.982700e+10 -4.972000e+10
#
#                                     2015-12-31
# Accounts Payable                  1.080000e+10
# Capital Surplus                   4.834000e+09
# Cash                              1.130200e+10
# Common Stock                      5.061000e+09
# Deferred Long Term Asset Charges  2.650000e+08
# Good Will                         5.126000e+09
# Intangible Assets                 2.657000e+09
# Inventory                         4.725700e+10
# Long Term Debt                    6.875000e+09
# Long Term Investments             1.284000e+09
# Minority Interest                 6.200000e+07
# Net Receivables                   8.713000e+09
# Net Tangible Assets              -1.448000e+09
# Other Assets                      1.673000e+09
# Other Current Assets                       NaN
# Other Current Liab                2.758900e+10
# Other Liab                        2.886900e+10
# Other Stockholder Equity         -1.274800e+10
# Property Plant Equipment          1.207600e+10
# Retained Earnings                 3.875600e+10
# Short Long Term Debt              7.340000e+08
# Short Term Investments            7.500000e+08
# Total Assets                      9.440800e+10
# Total Current Assets              6.823400e+10
# Total Current Liabilities         5.041200e+10
# Total Liab                        8.801100e+10
# Total Stockholder Equity          6.335000e+09
# Treasury Stock                   -4.231600e+10

# %%
ALL_DATA['show balance sheet'][1] # quarterly report
# Out:
#                                     2019-09-30    2019-06-30    2019-03-31  \
# Accounts Payable                  1.510100e+10  1.526700e+10  1.469300e+10
# Capital Surplus                   6.688000e+09  6.638000e+09  6.573000e+09
# Cash                              9.763000e+09  9.167000e+09  6.836000e+09
# Common Stock                      5.061000e+09  5.061000e+09  5.061000e+09
# Deferred Long Term Asset Charges  2.960000e+08  3.570000e+08  2.810000e+08
# Good Will                         8.063000e+09  8.051000e+09  7.967000e+09
# Intangible Assets                 3.587000e+09  3.761000e+09  3.498000e+09
# Inventory                         7.327900e+10  6.849200e+10  6.536900e+10
# Long Term Debt                    1.909800e+10  1.365900e+10  1.006300e+10
# Long Term Investments             1.117000e+09  1.142000e+09  1.183000e+09
# Minority Interest                 3.070000e+08  3.790000e+08  1.070000e+08
# Net Receivables                   1.464200e+10  1.353800e+10  1.387700e+10
# Net Tangible Assets              -1.576600e+10 -1.713400e+10 -1.134000e+10
# Other Assets                      2.507000e+09  2.392000e+09  2.214000e+09
# Other Current Assets              2.656000e+09  3.304000e+09  2.194000e+09
# Other Current Liab                5.337900e+10  5.267100e+10  5.266100e+10
# Other Liab                        2.329400e+10  2.329000e+10  2.417600e+10
# Other Stockholder Equity         -1.492700e+10 -1.490800e+10 -1.496900e+10
# Property Plant Equipment          1.359100e+10  1.366500e+10  1.360200e+10
# Retained Earnings                 5.398600e+10  5.281900e+10  5.809000e+10
# Short Long Term Debt              3.654000e+09  3.657000e+09  2.581000e+09
# Short Term Investments            1.150000e+09  4.390000e+08  8.930000e+08
# Total Assets                      1.325980e+11  1.262610e+11  1.202090e+11
# Total Current Assets              1.016560e+11  9.511100e+10  8.950900e+10
# Total Current Liabilities         9.184600e+10  9.218900e+10  8.361500e+10
# Total Liab                        1.364070e+11  1.312040e+11  1.199770e+11
# Total Stockholder Equity         -4.116000e+09 -5.322000e+09  1.250000e+08
# Treasury Stock                   -6.985100e+10 -6.984000e+10 -6.959900e+10
#
#                                     2018-12-31
# Accounts Payable                  1.291600e+10
# Capital Surplus                   6.768000e+09
# Cash                              7.637000e+09
# Common Stock                      5.061000e+09
# Deferred Long Term Asset Charges  2.840000e+08
# Good Will                         7.840000e+09
# Intangible Assets                 3.429000e+09
# Inventory                         6.256700e+10
# Long Term Debt                    8.670000e+09
# Long Term Investments             1.087000e+09
# Minority Interest                 7.100000e+07
# Net Receivables                   1.390400e+10
# Net Tangible Assets              -1.093000e+10
# Other Assets                      2.110000e+09
# Other Current Assets              2.335000e+09
# Other Current Liab                5.493600e+10
# Other Liab                        2.470200e+10
# Other Stockholder Equity         -1.508300e+10
# Property Plant Equipment          1.264500e+10
# Retained Earnings                 5.594100e+10
# Short Long Term Debt              2.690000e+09
# Short Term Investments            9.270000e+08
# Total Assets                      1.173590e+11
# Total Current Assets              8.783000e+10
# Total Current Liabilities         8.159000e+10
# Total Liab                        1.169490e+11
# Total Stockholder Equity          3.390000e+08
# Treasury Stock                   -6.743100e+10

# %% [markdown]
# The notebook ends here.
