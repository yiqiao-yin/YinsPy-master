# %% [markdown]
# # YIN'S CAPITAL XAI INITIATIVES: UCI Breast Cancer Data
#
# UCI ML Breast Cancer Wisconsin (Diagnostic) dataset is provided by Dr. William H. Wolberg, General Surgery Dept. University of Wisconsin at Clinical Sciences Center. Link can be accessed [here](https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+(Diagnostic)).
#
# Data Set Information:
#
# Features are computed from a digitized image of a fine needle aspirate (FNA) of a breast mass. They describe characteristics of the cell nuclei present in the image.
#
# Separating plane described above was obtained using Multisurface Method-Tree (MSM-T) \[K. P. Bennett, "Decision Tree Construction Via Linear Programming." Proceedings of the 4th Midwest Artificial Intelligence and Cognitive Science Society, pp. 97-101, 1992\], a classification method which uses linear programming to construct a decision tree. Relevant features were selected using an exhaustive search in the space of 1-4 features and 1-3 separating planes.
#
# The actual linear program used to obtain the separating plane in the 3-dimensional space is that described in: \[K. P. Bennett and O. L. Mangasarian: "Robust Linear Programming Discrimination of Two Linearly Inseparable Sets", Optimization Methods and Software 1, 1992, 23-34\].

# %% [markdown]
# ### Environment Initiation

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
from sklearn.model_selection import train_test_split
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from mlxtend.feature_selection import ExhaustiveFeatureSelector as EFS
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier

# %% [markdown]
# ### Loading Data

# %%
from sklearn.datasets import load_breast_cancer
data = load_breast_cancer()
data = pd.DataFrame(
    np.c_[data['data'], data['target']],
    columns= np.append(data['feature_names'], ['target']))

# %% [markdown]
# ### Create Training and Testing Set

# %%
X_train, X_test, y_train, y_test = train_test_split(
    data.drop(labels=['target'], axis=1), 
    data.target, test_size=0.2,
    random_state=0)
X_train.shape, X_test.shape
# Out:
# ((455, 30), (114, 30))

# %%
X_train.head()
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 338        10.05         17.53           64.41      310.8          0.10070
# 427        10.80         21.98           68.79      359.9          0.08801
# 406        16.14         14.86          104.30      800.0          0.09495
# 96         12.18         17.84           77.79      451.1          0.10450
# 490        12.25         22.44           78.18      466.5          0.08192
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 338           0.07326         0.02511              0.01775         0.1890
# 427           0.05743         0.03614              0.01404         0.2016
# 406           0.08501         0.05500              0.04528         0.1735
# 96            0.07057         0.02490              0.02941         0.1900
# 490           0.05200         0.01714              0.01261         0.1544
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# 338                 0.06331  ...         11.16          26.84
# 427                 0.05977  ...         12.76          32.04
# 406                 0.05875  ...         17.71          19.58
# 96                  0.06635  ...         12.83          20.92
# 490                 0.05976  ...         14.17          31.99
#
#      worst perimeter  worst area  worst smoothness  worst compactness  \
# 338            71.98       384.0            0.1402            0.14020
# 427            83.69       489.5            0.1303            0.16960
# 406           115.90       947.9            0.1206            0.17220
# 96             82.14       495.2            0.1140            0.09358
# 490            92.74       622.9            0.1256            0.18040
#
#      worst concavity  worst concave points  worst symmetry  \
# 338           0.1055               0.06499          0.2894
# 427           0.1927               0.07485          0.2965
# 406           0.2310               0.11290          0.2778
# 96            0.0498               0.05882          0.2227
# 490           0.1230               0.06335          0.3100
#
#      worst fractal dimension
# 338                  0.07664
# 427                  0.07662
# 406                  0.07012
# 96                   0.07376
# 490                  0.08203
#
# [5 rows x 30 columns]

# %%
X_test.head()
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 512        13.40         20.52           88.64      556.7          0.11060
# 457        13.21         25.25           84.10      537.9          0.08791
# 439        14.02         15.66           89.59      606.5          0.07966
# 298        14.26         18.17           91.22      633.1          0.06576
# 37         13.03         18.42           82.61      523.8          0.08983
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 512           0.14690         0.14450              0.08172         0.2116
# 457           0.05205         0.02772              0.02068         0.1619
# 439           0.05581         0.02087              0.02652         0.1589
# 298           0.05220         0.02475              0.01374         0.1635
# 37            0.03766         0.02562              0.02923         0.1467
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# 512                 0.07325  ...         16.41          29.66
# 457                 0.05584  ...         14.35          34.23
# 439                 0.05586  ...         14.91          19.31
# 298                 0.05586  ...         16.22          25.26
# 37                  0.05863  ...         13.30          22.81
#
#      worst perimeter  worst area  worst smoothness  worst compactness  \
# 512           113.30       844.4           0.15740            0.38560
# 457            91.29       632.9           0.12890            0.10630
# 439            96.53       688.9           0.10340            0.10170
# 298           105.80       819.7           0.09445            0.21670
# 37             84.46       545.9           0.09701            0.04619
#
#      worst concavity  worst concave points  worst symmetry  \
# 512          0.51060               0.20510          0.3585
# 457          0.13900               0.06005          0.2444
# 439          0.06260               0.08216          0.2136
# 298          0.15650               0.07530          0.2636
# 37           0.04833               0.05013          0.1987
#
#      worst fractal dimension
# 512                  0.11090
# 457                  0.06788
# 439                  0.06710
# 298                  0.07676
# 37                   0.06169
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Feature Selection (Forward) through ROC/AUC of Random Forest Classifier

# %%
# step forward feature selection
# select top 10 features based on the optimal roc_auc and RandomForest Classifier

sfs1 = SFS(RandomForestClassifier(n_jobs=-1,n_estimators=5), 
           k_features=10, 
           forward=True, 
           floating=False, 
           verbose=1,
           scoring='roc_auc',
           cv=3)

sfs1 = sfs1.fit(np.array(X_train), y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:   46.9s finished
# Features: 1/10[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:   10.0s finished
# Features: 2/10[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:    9.6s finished
# Features: 3/10[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:    9.4s finished
# Features: 4/10[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:    9.2s finished
# Features: 5/10[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:    8.7s finished
# Features: 6/10[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:    8.5s finished
# Features: 7/10[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:    8.0s finished
# Features: 8/10[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    7.7s finished
# Features: 9/10[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:    7.4s finished
# Features: 10/10

# %%
list(sfs1.k_feature_idx_)
# Out:
# [3, 4, 13, 15, 20, 21, 22, 24, 25, 28]

# %%
selected_feat1= X_train.columns[list(sfs1.k_feature_idx_)]
selected_feat1
# Out:
# Index(['mean area', 'mean smoothness', 'area error', 'compactness error',
#        'worst radius', 'worst texture', 'worst perimeter', 'worst smoothness',
#        'worst compactness', 'worst symmetry'],
#       dtype='object')

# %%
X_train[X_train.columns[list(sfs1.k_feature_idx_)]].head()
# Out:
#      mean area  mean smoothness  area error  compactness error  worst radius  \
# 338      310.8          0.10070       16.85            0.01449         11.16
# 427      359.9          0.08801       20.20            0.02148         12.76
# 406      800.0          0.09495       21.83            0.01246         17.71
# 96       451.1          0.10450       24.44            0.01179         12.83
# 490      466.5          0.08192       18.04            0.01205         14.17
#
#      worst texture  worst perimeter  worst smoothness  worst compactness  \
# 338          26.84            71.98            0.1402            0.14020
# 427          32.04            83.69            0.1303            0.16960
# 406          19.58           115.90            0.1206            0.17220
# 96           20.92            82.14            0.1140            0.09358
# 490          31.99            92.74            0.1256            0.18040
#
#      worst symmetry
# 338          0.2894
# 427          0.2965
# 406          0.2778
# 96           0.2227
# 490          0.3100

# %% [markdown]
# ### Feature Selection (Backward) through ROC/AUC of Random Forest Classifier

# %%
# step backward feature selection
# select top 10 features based on the optimal roc_auc and RandomForest Classifier

sfs2 = SFS(RandomForestClassifier(n_jobs=-1,n_estimators=5), 
           k_features=10, 
           forward=False, 
           floating=False, 
           verbose=1,
           scoring='roc_auc',
           cv=3)

sfs2 = sfs2.fit(np.array(X_train.fillna(0)), y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:   10.6s finished
# Features: 29/10[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:   10.3s finished
# Features: 28/10[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:    9.9s finished
# Features: 27/10[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:    9.4s finished
# Features: 26/10[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:    9.0s finished
# Features: 25/10[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:    8.8s finished
# Features: 24/10[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:    8.4s finished
# Features: 23/10[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:    8.1s finished
# Features: 22/10[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    7.8s finished
# Features: 21/10[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:    7.6s finished
# Features: 20/10[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:    7.0s finished
# Features: 19/10[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    6.6s finished
# Features: 18/10[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:    6.3s finished
# Features: 17/10[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:    5.9s finished
# Features: 16/10[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:    5.6s finished
# Features: 15/10[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    5.4s finished
# Features: 14/10[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:    4.9s finished
# Features: 13/10[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:    4.5s finished
# Features: 12/10[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    4.2s finished
# Features: 11/10[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:    3.8s finished
# Features: 10/10

# %%
selected_feat2= X_train.columns[list(sfs2.k_feature_idx_)]
selected_feat2
# Out:
# Index(['mean perimeter', 'mean fractal dimension', 'radius error',
#        'area error', 'concave points error', 'symmetry error', 'worst texture',
#        'worst area', 'worst smoothness', 'worst concavity'],
#       dtype='object')

# %%
X_train[X_train.columns[list(sfs2.k_feature_idx_)]].head()
# Out:
#      mean perimeter  mean fractal dimension  radius error  area error  \
# 338           64.41                 0.06331        0.2619       16.85
# 427           68.79                 0.05977        0.3077       20.20
# 406          104.30                 0.05875        0.2387       21.83
# 96            77.79                 0.06635        0.3661       24.44
# 490           78.18                 0.05976        0.2239       18.04
#
#      concave points error  symmetry error  worst texture  worst area  \
# 338              0.008043         0.02100          26.84       384.0
# 427              0.010450         0.01844          32.04       489.5
# 406              0.008747         0.01500          19.58       947.9
# 96               0.015190         0.02220          20.92       495.2
# 490              0.004551         0.01608          31.99       622.9
#
#      worst smoothness  worst concavity
# 338            0.1402           0.1055
# 427            0.1303           0.1927
# 406            0.1206           0.2310
# 96             0.1140           0.0498
# 490            0.1256           0.1230

# %% [markdown]
# ### Feature Selection (Both) through ROC/AUC of Random Forest Classifier

# %%
efs3 = EFS(RandomForestClassifier(n_jobs=-1,n_estimators=5, random_state=0), 
           min_features=1,
           max_features=6, 
           scoring='roc_auc',
           print_progress=True,
           cv=2)

# in order to shorter search time for the demonstration
# we only try all possible 1,2,3,4,5,6
# feature combinations from a dataset of 10 features

efs3 = efs3.fit(np.array(X_train[X_train.columns[0:10]].fillna(0)), y_train)
# Out:
# Features: 847/847

# %%
selected_feat3= X_train.columns[list(efs3.best_idx_)]
selected_feat3
# Out:
# Index(['mean radius', 'mean texture', 'mean area', 'mean smoothness',
#        'mean concavity'],
#       dtype='object')

# %%
X_train[X_train.columns[list(efs3.best_idx_)]].head()
# Out:
#      mean radius  mean texture  mean area  mean smoothness  mean concavity
# 338        10.05         17.53      310.8          0.10070         0.02511
# 427        10.80         21.98      359.9          0.08801         0.03614
# 406        16.14         14.86      800.0          0.09495         0.05500
# 96         12.18         17.84      451.1          0.10450         0.02490
# 490        12.25         22.44      466.5          0.08192         0.01714

# %% [markdown]
# ### Interaction-based Feature Selection / Feature Engineer

# %%
# %run "../scripts/InteractionBasedLearning.py"
# Out:
# ---------------------------------------------------------------------
#
#         Yin's Interaction-based Learning Statistical Package
#         Copyright © YINS CAPITAL, 2009 – Present
#         For more information, please go to www.YinsCapital.com
#
# README:
# This script has the following functions:
#
#     (1) iscore(): this function computes the I-score of selected X at predicting Y
#     (2) BDA(): this function runs through Backward Dropping Algorithm once
#     (3) InteractionLearning(): this function runs many rounds of BDA and
#                                finalize the variables selcted according to I-score
#
# ---------------------------------------------------------------------

# %%
X_train.shape, X_test.shape, len(y_train), len(y_test)
# Out:
# ((455, 30), (114, 30), 455, 114)

# %%
def helpDiscretize(X):
    return (X > X.mean()).astype(int)

# %%
X_train_dis = X_train.apply(helpDiscretize, axis=1)
X_test_dis = X_test.apply(helpDiscretize, axis=1)

# %%
X_train.shape, X_test.shape
# Out:
# ((455, 30), (114, 30))

# %%
X_train.iloc[:2,:2]
# Out:
#      mean radius  mean texture
# 338        10.05         17.53
# 427        10.80         21.98

# %%
X_train_dis.iloc[:2,:2]
# Out:
#      mean radius  mean texture
# 338            0             0
# 427            0             0

# %%
tmpResult = InteractionBasedLearning.InteractionLearning(
    newX=pd.concat([X_train_dis, X_test_dis]),
    y=np.concatenate([y_train, y_test]),
    testSize=round(455/(455+114), 1),
    num_initial_draw=7,
    total_rounds=100,
    top_how_many=3,
    nameExists=True,
    TYPE=str,
    verbatim=True)
# Out:
# 100%|██████████████████████████████████████████| 100/100 [01:09<00:00,  1.45it/s]
# Time Consumption (in sec): 69.21
# Time Consumption (in min): 1.15
# Time Consumption (in hr): 0.02

# %%
AllVarbyI = np.concatenate(
    [tmpResult['Brief'].iloc[0, :]['Modules'], 
     tmpResult['Brief'].iloc[1, :]['Modules'], 
     tmpResult['Brief'].iloc[2, :]['Modules']])

# %%
AllVarbyI[0]
# Out:
# array(['mean perimeter', 'area error', 'compactness error',
#        'concave points error', 'worst radius', 'worst symmetry'],
#       dtype=object)

# %%
variablesByI = []
for i in range(3):
    tempARRAY = AllVarbyI[i]
    for j in range(len(tempARRAY)):
        variablesByI.append(tempARRAY[j])

# %%
uniqueVarByI = [variablesByI[0]]
for i in variablesByI:
    if i not in uniqueVarByI:
        uniqueVarByI.append(i)

# %%
uniqueVarByI, len(uniqueVarByI)
# Out:
# (['mean perimeter',
#   'area error',
#   'compactness error',
#   'concave points error',
#   'worst radius',
#   'worst symmetry',
#   'mean area',
#   'mean smoothness',
#   'symmetry error',
#   'mean texture',
#   'mean symmetry',
#   'perimeter error',
#   'worst area',
#   'worst fractal dimension'],
#  14)

# %%
tmpResult['New Data'].head(2), tmpResult['New Data'].shape
# Out:
# (   mean perimeter  mean concave points  area error  symmetry error  \
#  0               1                    0           0               0
#  1               1                    0           0               0
#
#     worst concave points  worst symmetry         0  mean perimeter  \
#  0                     0               0  0.669246               1
#  1                     0               0  0.669246               1
#
#     mean fractal dimension  smoothness error  ...  concave points error  \
#  0                       0                 0  ...                     0
#  1                       0                 0  ...                     0
#
#     worst fractal dimension         0  radius error  area error  \
#  0                        0  0.649091             0           0
#  1                        0  0.649091             0           0
#
#     compactness error  worst smoothness  worst concavity  \
#  0                  0                 0                0
#  1                  0                 0                0
#
#     worst fractal dimension         0
#  0                        0  0.654064
#  1                        0  0.654064
#
#  [2 rows x 21 columns], (569, 21))

# %% [markdown]
# ### Selected Feature Comparison

# %% [markdown]
# Let us summarize the features for comparison.
#
# | Methods | # | Features  |
# | -------------------------- |:---------:| ------------:|
# | Forward           | 10 | 'mean radius', 'mean perimeter', 'mean symmetry', 'radius error', 'perimeter error', 'area error', 'concavity error', 'worst texture', 'worst perimeter', 'worst concave points' |
# | Backward          | 10 | 'mean texture', 'mean smoothness', 'mean compactness', 'radius error', 'concavity error', 'concave points error', 'worst perimeter', 'worst smoothness', 'worst concavity', 'worst symmetry' |
# | Both (Exhaustive) | 5 | 'mean radius', 'mean texture', 'mean area', 'mean smoothness', 'mean concavity' |
# | Influence Score   | 14  | \['mean perimeter', 'texture error', 'area error', 'smoothness error', 'worst radius', 'worst concave points', 'mean fractal dimension', 'concavity error', 'concave points error', 'worst area', 'mean concave points', 'mean symmetry', 'worst smoothness', 'worst concavity'\] |

# %% [markdown]
# ### Machine Learning: Cross-validation, Constructing Deep Learning Architecture, Prediction

# %%
# %run "../scripts/YinsDL.py"
# Out:
# ---------------------------------------------------------------------
#
#         Yin's Deep Learning Package
#         Copyright © YINS CAPITAL, 2009 – Present
#         For more information, please go to www.YinsCapital.com
#
# ---------------------------------------------------------------------

# %%
X_train[X_train.columns[list(sfs1.k_feature_idx_)]].head(3)
# Out:
#      mean area  mean smoothness  area error  compactness error  worst radius  \
# 338      310.8          0.10070       16.85            0.01449         11.16
# 427      359.9          0.08801       20.20            0.02148         12.76
# 406      800.0          0.09495       21.83            0.01246         17.71
#
#      worst texture  worst perimeter  worst smoothness  worst compactness  \
# 338          26.84            71.98            0.1402             0.1402
# 427          32.04            83.69            0.1303             0.1696
# 406          19.58           115.90            0.1206             0.1722
#
#      worst symmetry
# 338          0.2894
# 427          0.2965
# 406          0.2778

# %%
X_test[X_test.columns[list(sfs1.k_feature_idx_)]].head(3)
# Out:
#      mean area  mean smoothness  area error  compactness error  worst radius  \
# 512      556.7          0.11060       33.67           0.022650         16.41
# 457      537.9          0.08791       17.58           0.008082         14.35
# 439      606.5          0.07966       19.25           0.009238         14.91
#
#      worst texture  worst perimeter  worst smoothness  worst compactness  \
# 512          29.66           113.30            0.1574             0.3856
# 457          34.23            91.29            0.1289             0.1063
# 439          19.31            96.53            0.1034             0.1017
#
#      worst symmetry
# 512          0.3585
# 457          0.2444
# 439          0.2136

# %%
testresult = YinsDL.NN3_Classifier(
    X_train[X_train.columns[list(sfs1.k_feature_idx_)]], y_train, 
    X_test[X_test.columns[list(sfs1.k_feature_idx_)]], y_test, 
    l1_act='relu', l2_act='relu', l3_act='softmax',
    layer1size=128, layer2size=64, layer3size=2,
    num_of_epochs=50, plotROC=True, verbose=True)
# Out:
# C:\Users\eagle\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Tensorflow Version:
# 2.0.0
# Summary of Network Architecture:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               1408
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 9,794
# Trainable params: 9,794
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 455 samples
# Epoch 1/50
# 455/455 [==============================] - 1s 2ms/sample - loss: 0.6392 - accuracy: 0.6374
# Epoch 2/50
# 455/455 [==============================] - 0s 60us/sample - loss: 0.6031 - accuracy: 0.6637
# Epoch 3/50
# 455/455 [==============================] - 0s 69us/sample - loss: 0.5672 - accuracy: 0.7165
# Epoch 4/50
# 455/455 [==============================] - 0s 95us/sample - loss: 0.5495 - accuracy: 0.7165
# Epoch 5/50
# 455/455 [==============================] - 0s 93us/sample - loss: 0.5133 - accuracy: 0.7714
# Epoch 6/50
# 455/455 [==============================] - 0s 66us/sample - loss: 0.4890 - accuracy: 0.8176
# Epoch 7/50
# 455/455 [==============================] - 0s 111us/sample - loss: 0.5061 - accuracy: 0.7604
# Epoch 8/50
# 455/455 [==============================] - 0s 123us/sample - loss: 0.4715 - accuracy: 0.8066
# Epoch 9/50
# 455/455 [==============================] - 0s 118us/sample - loss: 0.4400 - accuracy: 0.8352
# Epoch 10/50
# 455/455 [==============================] - 0s 108us/sample - loss: 0.4368 - accuracy: 0.8220
# Epoch 11/50
# 455/455 [==============================] - 0s 119us/sample - loss: 0.4405 - accuracy: 0.8088
# Epoch 12/50
# 455/455 [==============================] - 0s 118us/sample - loss: 0.4149 - accuracy: 0.8264
# Epoch 13/50
# 455/455 [==============================] - 0s 112us/sample - loss: 0.4095 - accuracy: 0.8527
# Epoch 14/50
# 455/455 [==============================] - 0s 100us/sample - loss: 0.4223 - accuracy: 0.8396
# Epoch 15/50
# 455/455 [==============================] - 0s 115us/sample - loss: 0.4051 - accuracy: 0.8505
# Epoch 16/50
# 455/455 [==============================] - 0s 112us/sample - loss: 0.4258 - accuracy: 0.8396
# Epoch 17/50
# 455/455 [==============================] - 0s 117us/sample - loss: 0.4102 - accuracy: 0.8505
# Epoch 18/50
# 455/455 [==============================] - 0s 121us/sample - loss: 0.4196 - accuracy: 0.8374
# Epoch 19/50
# 455/455 [==============================] - 0s 110us/sample - loss: 0.4102 - accuracy: 0.8374
# Epoch 20/50
# 455/455 [==============================] - 0s 87us/sample - loss: 0.4104 - accuracy: 0.8396
# Epoch 21/50
# 455/455 [==============================] - 0s 68us/sample - loss: 0.4000 - accuracy: 0.8462
# Epoch 22/50
# 455/455 [==============================] - 0s 91us/sample - loss: 0.3991 - accuracy: 0.8330
# Epoch 23/50
# 455/455 [==============================] - 0s 109us/sample - loss: 0.4057 - accuracy: 0.8396
# Epoch 24/50
# 455/455 [==============================] - 0s 109us/sample - loss: 0.4073 - accuracy: 0.8396
# Epoch 25/50
# 455/455 [==============================] - 0s 117us/sample - loss: 0.3976 - accuracy: 0.8462
# Epoch 26/50
# 455/455 [==============================] - 0s 86us/sample - loss: 0.3928 - accuracy: 0.8462
# Epoch 27/50
# 455/455 [==============================] - 0s 96us/sample - loss: 0.3935 - accuracy: 0.8505
# Epoch 28/50
# 455/455 [==============================] - 0s 108us/sample - loss: 0.3922 - accuracy: 0.8505
# Epoch 29/50
# 455/455 [==============================] - 0s 112us/sample - loss: 0
#
#      concave points error  symmetry error  worst texture  worst area  \
# 338              0.008043         0.02100          26.84       384.0
# 427              0.010450         0.01844          32.04       489.5
# 406              0.008747         0.01500          19.58       947.9
#
#      worst smoothness  worst concavity
# 338            0.1402           0.1055
# 427            0.1303           0.1927
# 406            0.1206           0.2310

# %%
X_test[X_test.columns[list(sfs2.k_feature_idx_)]].head(3)
# Out:
#      mean perimeter  mean fractal dimension  radius error  area error  \
# 512           88.64                 0.07325        0.3906       33.67
# 457           84.10                 0.05584        0.2084       17.58
# 439           89.59                 0.05586        0.2142       19.25
#
#      concave points error  symmetry error  worst texture  worst area  \
# 512              0.013340         0.01705          29.66       844.4
# 457              0.006451         0.01347          34.23       632.9
# 439              0.010760         0.01171          19.31       688.9
#
#      worst smoothness  worst concavity
# 512            0.1574           0.5106
# 457            0.1289           0.1390
# 439            0.1034           0.0626

# %%
testresult = YinsDL.NN3_Classifier(
    X_train[X_train.columns[list(sfs2.k_feature_idx_)]], y_train, 
    X_test[X_test.columns[list(sfs2.k_feature_idx_)]], y_test, 
    l1_act='relu', l2_act='relu', l3_act='softmax',
    layer1size=128, layer2size=64, layer3size=2,
    num_of_epochs=50, plotROC=True, verbose=True)
# Out:
# Tensorflow Version:
# 2.0.0
# Summary of Network Architecture:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 128)               1408
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 9,794
# Trainable params: 9,794
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 455 samples
# Epoch 1/50
# 455/455 [==============================] - 0s 366us/sample - loss: 0.6608 - accuracy: 0.6066
# Epoch 2/50
# 455/455 [==============================] - 0s 68us/sample - loss: 0.6170 - accuracy: 0.6374
# Epoch 3/50
# 455/455 [==============================] - 0s 81us/sample - loss: 0.5940 - accuracy: 0.6879
# Epoch 4/50
# 455/455 [==============================] - 0s 77us/sample - loss: 0.5615 - accuracy: 0.6725
# Epoch 5/50
# 455/455 [==============================] - 0s 62us/sample - loss: 0.5316 - accuracy: 0.7429
# Epoch 6/50
# 455/455 [==============================] - 0s 85us/sample - loss: 0.4778 - accuracy: 0.8440
# Epoch 7/50
# 455/455 [==============================] - 0s 70us/sample - loss: 0.4341 - accuracy: 0.8549
# Epoch 8/50
# 455/455 [==============================] - 0s 76us/sample - loss: 0.3861 - accuracy: 0.8769
# Epoch 9/50
# 455/455 [==============================] - 0s 60us/sample - loss: 0.3680 - accuracy: 0.8725
# Epoch 10/50
# 455/455 [==============================] - 0s 54us/sample - loss: 0.3127 - accuracy: 0.8967
# Epoch 11/50
# 455/455 [==============================] - 0s 44us/sample - loss: 0.2879 - accuracy: 0.9077
# Epoch 12/50
# 455/455 [==============================] - 0s 48us/sample - loss: 0.2733 - accuracy: 0.9011
# Epoch 13/50
# 455/455 [==============================] - 0s 59us/sample - loss: 0.2563 - accuracy: 0.8945
# Epoch 14/50
# 455/455 [==============================] - 0s 46us/sample - loss: 0.2390 - accuracy: 0.9011
# Epoch 15/50
# 455/455 [==============================] - 0s 48us/sample - loss: 0.2287 - accuracy: 0.9033
# Epoch 16/50
# 455/455 [==============================] - 0s 45us/sample - loss: 0.2196 - accuracy: 0.9121
# 455/455 [==============================] - 0s 61us/sample - loss: 0.1941 - accuracy: 0.9187
# Epoch 48/50
# 455/455 [==============================] - 0s 48us/sample - loss: 0.1986 - accuracy: 0.9187
# Epoch 49/50
# 455/455 [==============================] - 0s 60us/sample - loss: 0.2168 - accuracy: 0.9165
# Epoch 50/50
# 455/455 [==============================] - 0s 57us/sample - loss: 0.1889 - accuracy: 0.9187
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Confusion Matrix:
#     0   1
# 0  44   3
# 1   8  59
# Test Accuracy: 0.9035
# Test AUC: 0.9083836138456653

# %%
X_train[X_train.columns[list(efs3.best_idx_)]].head(3)
# Out:
#      mean radius  mean texture  mean area  mean smoothness  mean concavity
# 338        10.05         17.53      310.8          0.10070         0.02511
# 427        10.80         21.98      359.9          0.08801         0.03614
# 406        16.14         14.86      800.0          0.09495         0.05500

# %%
X_test[X_test.columns[list(efs3.best_idx_)]].head(3)
# Out:
#      mean radius  mean texture  mean area  mean smoothness  mean concavity
# 512        13.40         20.52      556.7          0.11060         0.14450
# 457        13.21         25.25      537.9          0.08791         0.02772
# 439        14.02         15.66      606.5          0.07966         0.02087

# %%
testresult = YinsDL.NN3_Classifier(
    X_train[X_train.columns[list(efs3.best_idx_)]], y_train, 
    X_test[X_test.columns[list(efs3.best_idx_)]], y_test, 
    l1_act='relu', l2_act='relu', l3_act='softmax',
    layer1size=128, layer2size=64, layer3size=2,
    num_of_epochs=50, plotROC=True, verbose=True)
# Out:
# Tensorflow Version:
# 2.0.0
# Summary of Network Architecture:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 128)               768
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 9,154
# Trainable params: 9,154
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 455 samples
# Epoch 1/50
# 455/455 [==============================] - 0s 364us/sample - loss: 0.6577 - accuracy: 0.6374
# Epoch 2/50
# 455/455 [==============================] - 0s 72us/sample - loss: 0.6564 - accuracy: 0.6374
# Epoch 3/50
# 455/455 [==============================] - 0s 77us/sample - loss: 0.6553 - accuracy: 0.6374
# Epoch 4/50
# 455/455 [==============================] - 0s 51us/sample - loss: 0.6560 - accuracy: 0.6374
# Epoch 5/50
# 455/455 [==============================] - 0s 100us/sample - loss: 0.6536 - accuracy: 0.6374
# Epoch 6/50
# 455/455 [==============================] - 0s 95us/sample - loss: 0.6560 - accuracy: 0.6374
# Epoch 7/50
# 455/455 [==============================] - 0s 96us/sample - loss: 0.6530 - accuracy: 0.6374
# Epoch 8/50
# 455/455 [==============================] - 0s 97us/sample - loss: 0.6577 - accuracy: 0.6374
# Epoch 9/50
# 455/455 [==============================] - 0s 96us/sample - loss: 0.6565 - accuracy: 0.6374
# Epoch 10/50
# 455/455 [==============================] - 0s 117us/sample - loss: 0.6502 - accuracy: 0.6374
# Epoch 11/50
# 455/455 [==============================] - 0s 112us/sample - loss: 0
# Epoch 44/50
# 455/455 [==============================] - 0s 75us/sample - loss: 0.5801 - accuracy: 0.6967
# Epoch 45/50
# 455/455 [==============================] - 0s 62us/sample - loss: 0.5776 - accuracy: 0.6659
# Epoch 46/50
# 455/455 [==============================] - 0s 64us/sample - loss: 0.5691 - accuracy: 0.6813
# Epoch 47/50
# 455/455 [==============================] - 0s 69us/sample - loss: 0.5641 - accuracy: 0.7121
# Epoch 48/50
# 455/455 [==============================] - 0s 78us/sample - loss: 0.5501 - accuracy: 0.7297
# Epoch 49/50
# 455/455 [==============================] - 0s 67us/sample - loss: 0.5662 - accuracy: 0.6945
# Epoch 50/50
# 455/455 [==============================] - 0s 59us/sample - loss: 0.5549 - accuracy: 0.7165
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Confusion Matrix:
#     0   1
# 0  37  10
# 1  21  46
# Test Accuracy: 0.7281
# Test AUC: 0.736900603366148

# %%
X_train[uniqueVarByI].head(3)
# Out:
#      mean perimeter  area error  compactness error  concave points error  \
# 338           64.41       16.85            0.01449              0.008043
# 427           68.79       20.20            0.02148              0.010450
# 406          104.30       21.83            0.01246              0.008747
#
#      worst radius  worst symmetry  mean area  mean smoothness  symmetry error  \
# 338         11.16          0.2894      310.8          0.10070         0.02100
# 427         12.76          0.2965      359.9          0.08801         0.01844
# 406         17.71          0.2778      800.0          0.09495         0.01500
#
#      mean texture  mean symmetry  perimeter error  worst area  \
# 338         17.53         0.1890            1.778       384.0
# 427         21.98         0.2016            2.240       489.5
# 406         14.86         0.1735            1.729       947.9
#
#      worst fractal dimension
# 338                  0.07664
# 427                  0.07662
# 406                  0.07012

# %%
X_test[uniqueVarByI].head(3)
# Out:
#      mean perimeter  area error  compactness error  concave points error  \
# 512           88.64       33.67           0.022650              0.013340
# 457           84.10       17.58           0.008082              0.006451
# 439           89.59       19.25           0.009238              0.010760
#
#      worst radius  worst symmetry  mean area  mean smoothness  symmetry error  \
# 512         16.41          0.3585      556.7          0.11060         0.01705
# 457         14.35          0.2444      537.9          0.08791         0.01347
# 439         14.91          0.2136      606.5          0.07966         0.01171
#
#      mean texture  mean symmetry  perimeter error  worst area  \
# 512         20.52         0.2116            3.093       844.4
# 457         25.25         0.1619            1.314       632.9
# 439         15.66         0.1589            1.606       688.9
#
#      worst fractal dimension
# 512                  0.11090
# 457                  0.06788
# 439                  0.06710

# %%
testresult = YinsDL.NN3_Classifier(
    X_train[uniqueVarByI], y_train, 
    X_test[uniqueVarByI], y_test, 
    l1_act='relu', l2_act='relu', l3_act='softmax',
    layer1size=128, layer2size=64, layer3size=2,
    num_of_epochs=50, plotROC=True, verbose=True)
# Out:
# Tensorflow Version:
# 2.0.0
# Summary of Network Architecture:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_42 (Dense)             (None, 128)               1920
# _________________________________________________________________
# dense_43 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_44 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 10,306
# Trainable params: 10,306
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on
# Epoch 33/50
# 455/455 [==============================] - 0s 63us/sample - loss: 0.1844 - accuracy: 0.9209
# Epoch 34/50
# 455/455 [==============================] - 0s 63us/sample - loss: 0.2126 - accuracy: 0.9209
# Epoch 35/50
# 455/455 [==============================] - 0s 61us/sample - loss: 0.2159 - accuracy: 0.9077
# Epoch 36/50
# 455/455 [==============================] - 0s 73us/sample - loss: 0.1814 - accuracy: 0.9297
# Epoch 37/50
# 455/455 [==============================] - 0s 69us/sample - loss: 0.1994 - accuracy: 0.9165
# Epoch 38/50
# 455/455 [==============================] - 0s 61us/sample - loss: 0.2054 - accuracy: 0.9165
# Epoch 39/50
# 455/455 [==============================] - 0s 65us/sample - loss: 0.1935 - accuracy: 0.9121
# Epoch 40/50
# 455/455 [==============================] - 0s 62us/sample - loss: 0.1910 - accuracy: 0.9143
# Epoch 41/50
# 455/455 [==============================] - 0s 81us/sample - loss: 0.1901 - accuracy: 0.9165
# Epoch 42/50
# 455/455 [==============================] - 0s 158us/sample - loss: 0.1879 - accuracy: 0.9209
# Epoch 43/50
# 455/455 [==============================] - 0s 106us/sample - loss: 0.1939 - accuracy: 0.9143
# Epoch 44/50
# 455/455 [==============================] - 0s 152us/sample - loss: 0.1939 - accuracy: 0.9253
# Epoch 45/50
# 455/455 [==============================] - 0s 70us/sample - loss: 0.1916 - accuracy: 0.9209
# Epoch 46/50
# 455/455 [==============================] - 0s 68us/sample - loss: 0.1998 - accuracy: 0.9231
# Epoch 47/50
# 455/455 [==============================] - 0s 68us/sample - loss: 0.1823 - accuracy: 0.9209
# Epoch 48/50
# 455/455 [==============================] - 0s 71us/sample - loss: 0.2011 - accuracy: 0.9121
# Epoch 49/50
# 455/455 [==============================] - 0s 71us/sample - loss: 0.1872 - accuracy: 0.9231
# Epoch 50/50
# 455/455 [==============================] - 0s 66us/sample - loss: 0.1893 - accuracy: 0.9143
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Confusion Matrix:
#     0   1
# 0  41   6
# 1   1  66
# Test Accuracy: 0.9386
# Test AUC: 0.9287075261987933

# %% [markdown]
# ### Performance Summary: Features and Test Set Accuracy

# %% [markdown]
# Let us summarize performance along with selected features.
#
# | Methods | # | Features  | Performance |
# | -------------------------- |:---------:| ------------:| ------------:|
# | Forward           | 10 | 'mean radius', 'mean perimeter', 'mean symmetry', 'radius error', 'perimeter error', 'area error', 'concavity error', 'worst texture', 'worst perimeter', 'worst concave points' | 0.79 |
# | Backward          | 10 | 'mean texture', 'mean smoothness', 'mean compactness', 'radius error', 'concavity error', 'concave points error', 'worst perimeter', 'worst smoothness', 'worst concavity', 'worst symmetry' | 0.91 |
# | Both (Exhaustive) | 5 | 'mean radius', 'mean texture', 'mean area', 'mean smoothness', 'mean concavity' | 0.74 |
# | Influence Score   | 14  | \['mean perimeter', 'texture error', 'area error', 'smoothness error', 'worst radius', 'worst concave points', 'mean fractal dimension', 'concavity error', 'concave points error', 'worst area', 'mean concave points', 'mean symmetry', 'worst smoothness', 'worst concavity'\] | 0.93 |

# %% [markdown]
# Investigation ends here.
